# %%
import warnings
warnings.filterwarnings("ignore")

# %%
import numpy as np
import pandas as pd
import tensorflow as tf

from collections import defaultdict
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import OneHotEncoder
from sklearn.metrics import classification_report, balanced_accuracy_score, roc_auc_score, average_precision_score, fbeta_score, matthews_corrcoef
from tensorflow.keras.callbacks import EarlyStopping
from tensorflow.keras.models import Model
from tensorflow.keras.layers import Input, Dense, Dropout, Lambda, Concatenate

# %%
# Custom function to build hidden combination (i.e. convolution) layers

def create_random_combination_layer(input_layer, combination_size, num_combinations, input_dim):
    outputs = []
    
    for _ in range(num_combinations):
        # First random feature selection
        indices_1 = np.random.choice(input_dim, combination_size, replace=False)
        indices_tensor_1 = tf.constant(indices_1, dtype=tf.int32)
        
        # First feature selection using Lambda layer
        slice_layer_1 = Lambda(
            lambda x: tf.gather(x, indices_tensor_1, axis=1),  # Gather selected features
            output_shape=(combination_size,)
        )(input_layer)
        
        # Second random feature selection (after the first random selection)
        indices_2 = np.random.choice(combination_size, combination_size, replace=False)
        indices_tensor_2 = tf.constant(indices_2, dtype=tf.int32)
        
        # Second feature selection using Lambda layer
        slice_layer_2 = Lambda(
            lambda x: tf.gather(x, indices_tensor_2, axis=1),  # Apply a second feature selection
            output_shape=(combination_size,)
        )(slice_layer_1)

        # Apply Dense layers on the final selected subset
        selected_features = Dense(16, activation='relu')(
            Dense(8, activation='relu')(
                Dense(4, activation='relu')(slice_layer_2)
            )
        )
        outputs.append(selected_features)
    
    # Concatenate the outputs from all the random feature combinations
    return Concatenate()(outputs)

# %%
def run_model(train_data_path, test_data_path, is_string_labels = False, label_mapping = None):

    # Initialize the one-hot encoder for the target
    encoder = OneHotEncoder(sparse_output=False)

    # Load and Prepare Training Data
    train_data = pd.read_csv(train_data_path)
    train_data = train_data.sample(frac=1).reset_index(drop=True)  # Shuffle
    if (is_string_labels):
        train_data['label'] = train_data['label'].map(label_mapping)
    train_X = train_data.drop(columns=['label']).values
    train_y = train_data['label'].values
    train_y = encoder.fit_transform(train_y.reshape(-1, 1))

    # Perform a stratified split into train and validation sets (80% train, 20% validation)
    X_train, X_val, y_train, y_val = train_test_split(train_X, train_y, test_size=0.2, random_state=42, stratify=train_y)

    # Load and Prepare Test Data (this will not be used in training)
    test_data = pd.read_csv(test_data_path)
    test_data = test_data.sample(frac=1).reset_index(drop=True)  # Shuffle
    if (is_string_labels):
        test_data['label'] = test_data['label'].map(label_mapping)
    test_X = test_data.drop(columns=['label']).values
    test_y = test_data['label'].values
    test_y = encoder.transform(test_y.reshape(-1, 1))

    # Parameters for Random Feature Combination
    num_combinations = 20  # Number of random column combinations
    combination_size = 3   # Number of columns in each combination

    # Number of features and classes of the original dataset
    num_features = train_X.shape[1]
    num_classes = train_y.shape[1]

    # EarlyStopping Callback (optional, to avoid overfitting)
    early_stopping = EarlyStopping(monitor='val_loss', patience=10, restore_best_weights=True)

    # Number of runs for averaging results
    num_runs = 5

    # Initialize storage for metrics
    metrics_storage = defaultdict(list)

    # Train the Model with Validation Split N tines for more accurate metrics
    print("Verbose output only for first run...")
    verbose_run = 1
    for run in range(num_runs):
        
        # Model is defined separately in each run, since the random combination layers
        # must be randomly initialized each time. Otherwise, the "random" indices stay the same
        # throughout all runs
        input_layer = Input(shape=(X_train.shape[1],))  # Input shape from the training data
        feature_layer = create_random_combination_layer(input_layer, combination_size, num_combinations, X_train.shape[1])
        hidden_layer = Dense(128, activation='relu')(feature_layer)
        hidden_layer = Dropout(0.5)(hidden_layer)
        output_layer = Dense(test_y.shape[1], activation='softmax')(hidden_layer)
        model = Model(inputs=input_layer, outputs=output_layer)
        model.compile(optimizer='adam', loss='categorical_crossentropy', metrics=['accuracy'])

        print(f"Run {run + 1}/{num_runs} started...")
        history = model.fit(
            X_train, y_train, 
            epochs=1000, 
            batch_size=256, 
            validation_data=(X_val, y_val),
            callbacks=[early_stopping],
            verbose=verbose_run
        )
        verbose_run = 0 # Suppress detailed output for multiple runs

        test_loss, test_acc = model.evaluate(test_X, test_y, verbose=0)
        y_pred = model.predict(test_X, verbose=0)
        y_pred_classes = y_pred.argmax(axis=1)
        y_true_classes = test_y.argmax(axis=1)

        # Compute metrics
        balanced_acc = balanced_accuracy_score(test_y, y_pred)
        roc_auc = roc_auc_score(test_y, y_pred, multi_class='ovr')
        pr_auc = average_precision_score(test_y, y_pred, average='weighted')
        f2 = fbeta_score(y_true_classes, y_pred_classes, beta=2, average='weighted')
        mcc = matthews_corrcoef(y_true_classes, y_pred_classes)

        # Store metrics
        metrics_storage['test_loss'].append(test_loss)
        metrics_storage['test_accuracy'].append(test_acc)
        metrics_storage['balanced_accuracy'].append(balanced_acc)
        metrics_storage['roc_auc'].append(roc_auc)
        metrics_storage['pr_auc'].append(pr_auc)
        metrics_storage['f2'].append(f2)
        metrics_storage['mcc'].append(mcc)

        # Store classification report metrics
        report = classification_report(y_true_classes, y_pred_classes, output_dict=True)
        for label, values in report.items():
            # Check if the value is a dictionary (e.g., 'precision', 'recall', 'f1-score')
            if isinstance(values, dict):
                for metric, value in values.items():
                    metrics_storage[f"{label}_{metric}"].append(value)
            else:
                # Handle scalar values (like 'accuracy')
                metrics_storage[label].append(values)

    # Average the metrics over all runs
    print("\nAggregated Metrics:")
    for metric, values in metrics_storage.items():
        avg_value = np.mean(values)
        print(f"{metric}: {avg_value:.4f}")

# %% [markdown]
# # Shuttle

# %%
run_model("shuttle_train.csv", "shuttle_test.csv", is_string_labels = False)
# Out:
# Verbose output only for first run...
# Run 1/5 started...
# Epoch 1/1000
# 145/145 ━━━━━━━━━━━━━━━━━━━━ 20s 12ms/step - accuracy: 0.7809 - loss: 0.7596 - val_accuracy: 0.9505 - val_loss: 0.1624
# Epoch 2/1000
# 145/145 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - accuracy: 0.9490 - loss: 0.1612 - val_accuracy: 0.9636 - val_loss: 0.1235
# Epoch 3/1000
# 145/145 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - accuracy: 0.9594 - loss: 0.1250 - val_accuracy: 0.9634 - val_loss: 0.1140
# Epoch 4/1000
# 145/145 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - accuracy: 0.9626 - loss: 0.1153 - val_accuracy: 0.9594 - val_loss: 0.1135
# Epoch 5/1000
# 145/145 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - accuracy: 0.9624 - loss: 0.1161 - val_accuracy: 0.9650 - val_loss: 0.1077
# Epoch 6/1000
# 145/145 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - accuracy: 0.9648 - loss: 0.1155 - val_accuracy: 0.9648 - val_loss: 0.1063
# Epoch 7/1000
# 145/145 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - accuracy: 0.9650 - loss: 0.1088 - val_accuracy: 0.9655 - val_loss: 0.1035
# Epoch 8/1000
# 145/145 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - accuracy: 0.9658 - loss: 0.1064 - val_accuracy: 0.9656 - val_loss: 0.1046
# Epoch 9/1000
# 145/145 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - accuracy: 0.9666 - loss: 0.1058 - val_accuracy: 0.9659 - val_loss: 0.1028
# Epoch 10/1000
# 145/145 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - accuracy: 0.
1000
# 145/145 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - accuracy: 0.9689 - loss: 0.0906 - val_accuracy: 0.9670 - val_loss: 0.0962
# Epoch 43/1000
# 145/145 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - accuracy: 0.9708 - loss: 0.0862 - val_accuracy: 0.9677 - val_loss: 0.0949
# Epoch 44/1000
# 145/145 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - accuracy: 0.9706 - loss: 0.0872 - val_accuracy: 0.9671 - val_loss: 0.0961
# Epoch 45/1000
# 145/145 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - accuracy: 0.9702 - loss: 0.0851 - val_accuracy: 0.9679 - val_loss: 0.0955
# Epoch 46/1000
# 145/145 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - accuracy: 0.9696 - loss: 0.0876 - val_accuracy: 0.9672 - val_loss: 0.0952
# Epoch 47/1000
# 145/145 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - accuracy: 0.9698 - loss: 0.0867 - val_accuracy: 0.9673 - val_loss: 0.0971
# Epoch 48/1000
# 145/145 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - accuracy: 0.9697 - loss: 0.0888 - val_accuracy: 0.9675 - val_loss: 0.0964
# Epoch 49/1000
# 145/145 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - accuracy: 0.9693 - loss: 0.0858 - val_accuracy: 0.9669 - val_loss: 0.0956
# Epoch 50/1000
# 145/145 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - accuracy: 0.9706 - loss: 0.0845 - val_accuracy: 0.9669 - val_loss: 0.0951
# Epoch 51/1000
# 145/145 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - accuracy: 0.9719 - loss: 0.0824 - val_accuracy: 0.9663 - val_loss: 0.0999
# Epoch 52/1000
# 145/145 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - accuracy: 0.9705 - loss: 0.0871 - val_accuracy: 0.9675 - val_loss: 0.0974
# Epoch 53/1000
# 145/145 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - accuracy: 0.9702 - loss: 0.0900 - val_accuracy: 0.9675 - val_loss: 0.0975
# Run 2/5 started...
# Run 3/5 started...
# Run 4/5 started...
# Run 5/5 started...
#
# Aggregated Metrics:
# test_loss: 0.1660
# test_accuracy: 0.9338
# roc_auc: 0.8572
# pr_auc: 0.9629
# f2: 0.9297
# mcc: 0.7963
# 0_precision: 0.9475
# 0_recall: 0.9821
# 0_f1-score: 0.9639
# 0_support: 9117.0000
# 1_precision: 0.3333
# 1_recall: 0.1800
# 1_f1-score: 0.2186
# 1_support: 10.0000
# 2_precision: 0.3889
# 2_recall: 0.1588
# 2_f1-score: 0.2217
# 2_support: 34.0000
# 3_precision: 0.8200
# 3_recall: 0.7105
# 3_f1-score: 0.7442
# 3_support: 1781.0000
# 4_precision: 0.9402
# 4_recall: 0.9277
# 4_f1-score: 0.9316
# 4_support: 653.0000
# 5_precision: 0.0000
# 5_recall: 0.0000
# 5_f1-score: 0.0000
# 5_support: 2.0000
# 6_precision: 0.0000
# 6_recall: 0.0000
# 6_f1-score: 0.0000
# 6_support: 3.0000
# accuracy: 0.9338
# macro avg_precision: 0.4900
# macro avg_recall: 0.4227
# macro avg_f1-score: 0.4400
# macro avg_support: 11600.0000
# weighted avg_precision: 0.9249
# weighted avg_recall: 0.9338
# weighted avg_f1-score: 0.9251
# weighted avg_support: 11600.0000

# %% [markdown]
# # Covertype

# %%
run_model("covtype_train.csv", "covtype_test.csv", is_string_labels = False)
# Out:
# Verbose output only for first run...
# Run 1/5 started...
# Epoch 1/1000
# 1453/1453 ━━━━━━━━━━━━━━━━━━━━ 29s 7ms/step - accuracy: 0.4731 - loss: 1.2464 - val_accuracy: 0.4919 - val_loss: 1.1745
# Epoch 2/1000
# 1453/1453 ━━━━━━━━━━━━━━━━━━━━ 10s 7ms/step - accuracy: 0.4912 - loss: 1.1854 - val_accuracy: 0.4917 - val_loss: 1.1745
# Epoch 3/1000
# 1453/1453 ━━━━━━━━━━━━━━━━━━━━ 9s 6ms/step - accuracy: 0.4927 - loss: 1.1782 - val_accuracy: 0.4919 - val_loss: 1.1724
# Epoch 4/1000
# 1453/1453 ━━━━━━━━━━━━━━━━━━━━ 10s 7ms/step - accuracy: 0.4949 - loss: 1.1781 - val_accuracy: 0.4966 - val_loss: 1.1716
# Epoch 5/1000
# 1453/1453 ━━━━━━━━━━━━━━━━━━━━ 10s 7ms/step - accuracy: 0.
━━━━━━━━━━━━━━━━━━━━ 10s 7ms/step - accuracy: 0.4938 - loss: 1.1739 - val_accuracy: 0.4969 - val_loss: 1.1695
# Run 2/5 started...
# Run 3/5 started...
# Run 4/5 started...
# Run 5/5 started...
#
# Aggregated Metrics:
# test_loss: 1.0590
# test_accuracy: 0.5393
# roc_auc: 0.6823
# pr_auc: 0.4740
# f2: 0.4814
# mcc: 0.1630
# 0_precision: 0.3772
# 0_recall: 0.1912
# 0_f1-score: 0.2175
# 0_support: 42368.0000
# 1_precision: 0.5439
# 1_recall: 0.9273
# 1_f1-score: 0.6758
# 1_support: 56661.0000
# 2_precision: 0.3032
# 2_recall: 0.2548
# 2_f1-score: 0.2522
# 2_support: 7151.0000
# 3_precision: 0.1111
# 3_recall: 0.0073
# 3_f1-score: 0.0137
# 3_support: 549.0000
# 4_precision: 0.0000
# 4_recall: 0.0000
# 4_f1-score: 0.0000
# 4_support: 1899.0000
# 5_precision: 0.1340
# 5_recall: 0.0041
# 5_f1-score: 0.0079
# 5_support: 3473.0000
# 6_precision: 0.3852
# 6_recall: 0.0445
# 6_f1-score: 0.0720
# 6_support: 4102.0000
# accuracy: 0.5393
# macro avg_precision: 0.2649
# macro avg_recall: 0.2042
# macro avg_f1-score: 0.1770
# macro avg_support: 116203.0000
# weighted avg_precision: 0.4395
# weighted avg_recall: 0.5393
# weighted avg_f1-score: 0.4272
# weighted avg_support: 116203.0000

# %% [markdown]
# # KDD

# %%
labels_map = {
    'normal.': 0, 'satan.': 1, 'ipsweep.': 2, 'portsweep.': 3, 'nmap.': 4,
    'back.': 5, 'warezclient.': 6, 'teardrop.': 7, 'pod.': 8, 'guess_passwd.': 9,
    'buffer_overflow.': 10, 'land.': 11, 'warezmaster.': 12, 'imap.': 13, 'rootkit.': 14,
    'loadmodule.': 15, 'multihop.': 16, 'ftp_write.': 17, 'phf.': 18, 'perl.': 19, 'spy.': 20
}

run_model("kdd_train.csv", "kdd_test.csv", is_string_labels = True, label_mapping = labels_map)
# Out:
# Verbose output only for first run...
# Run 1/5 started...
# Epoch 1/1000
# 2547/2547 ━━━━━━━━━━━━━━━━━━━━ 38s 8ms/step - accuracy: 0.9499 - loss: 0.3483 - val_accuracy: 0.9551 - val_loss: 0.2340
# Epoch 2/1000
# 2547/2547 ━━━━━━━━━━━━━━━━━━━━ 18s 7ms/step - accuracy: 0.9550 - loss: 0.2420 - val_accuracy: 0.9551 - val_loss: 0.2339
# Epoch 3/1000
# 2547/2547 ━━━━━━━━━━━━━━━━━━━━ 18s 7ms/step - accuracy: 0.9551 - loss: 0.2390 - val_accuracy: 0.9551 - val_loss: 0.2336
# Epoch 4/1000
# 2547/2547 ━━━━━━━━━━━━━━━━━━━━ 18s 7ms/step - accuracy: 0.9549 - loss: 0.2385 - val_accuracy: 0.9551 - val_loss: 0.2337
# Epoch 5/1000
# 2547/2547 ━━━━━━━━━━━━━━━━━━━━ 18s 7ms/step - accuracy: 0.9549 - loss: 0.2377 - val_accuracy: 0.9551 - val_loss: 0.2337
# Epoch 6/1000
# 2547/2547 ━━━━━━━━━━━━━━━━━━━━ 18s 7ms/step - accuracy: 0.9554 - loss: 0.2347 - val_accuracy: 0.9551 - val_loss: 0.2336
# Epoch 7/1000
# 2547/2547 ━━━━━━━━━━━━━━━━━━━━ 18s 7ms/step - accuracy: 0.9550 - loss: 0.2359 - val_accuracy: 0.9551 - val_loss: 0.2335
# Epoch 8/1000
# 2547/2547 ━━━━━━━━━━━━━━━━━━━━ 18s 7ms/step - accuracy: 0.9554 - loss: 0.2335 - val_accuracy: 0.9551 - val_loss: 0.2336
# Epoch 9/1000
# 2547/2547 ━━━━━━━━━━━━━━━━━━━━ 18s 7ms/step - accuracy: 0.9549 - loss: 0.2356 - val_accuracy: 0.9551 - val_loss: 0.2334
# Epoch 10/1000
# 2547/2547 ━━━━━━━━━━━━━━━━━━━━ 19s 7ms/step - accuracy: 0.9548 - loss: 0.2352 - val_accuracy: 0.9551 - val_loss: 0.2336
# Epoch 11/1000
# 2547/2547 ━━━━━━━━━━━━━━━━━━━━ 19s 8ms/step - accuracy: 0.9547 - loss: 0.2362 - val_accuracy: 0.9551 - val_loss: 0.2335
# Epoch 12/1000
# 2547/2547 ━━━━━━━━━━━━━━━━━━━━ 20s 8ms/step - accuracy: 0.9553 - loss: 0.2341 - val_accuracy: 0.9551 - val_loss: 0.2337
# Epoch 13/1000
# 2547/2547 ━━━━━━━━━━━━━━━━━━━━ 18s 7ms/step - accuracy: 0.
1000
# 2547/2547 ━━━━━━━━━━━━━━━━━━━━ 19s 7ms/step - accuracy: 0.9554 - loss: 0.2331 - val_accuracy: 0.9551 - val_loss: 0.2334
# Epoch 63/1000
# 2547/2547 ━━━━━━━━━━━━━━━━━━━━ 19s 7ms/step - accuracy: 0.9549 - loss: 0.2347 - val_accuracy: 0.9551 - val_loss: 0.2334
# Run 2/5 started...
# Run 3/5 started...
# Run 4/5 started...
# Run 5/5 started...
#
# Aggregated Metrics:
# test_loss: 0.2135
# test_accuracy: 0.9609
# roc_auc: 0.6080
# pr_auc: 0.9294
# f2: 0.9539
# mcc: 0.2695
# 0_precision: 0.9624
# 0_recall: 0.9992
# 0_f1-score: 0.9805
# 0_support: 194557.0000
# 1_precision: 0.4137
# 1_recall: 0.3121
# 1_f1-score: 0.3336
# 1_support: 3178.0000
# 2_precision: 0.0000
# 2_recall: 0.0000
# 2_f1-score: 0.0000
# 2_support: 2496.0000
# 3_precision: 0.7837
# 3_recall: 0.1481
# 3_f1-score: 0.1735
# 3_support: 2083.0000
# 4_precision: 0.1451
# 4_recall: 0.0799
# 4_f1-score: 0.1031
# 4_support: 463.0000
# 5_precision: 0.1647
# 5_recall: 0.0063
# 5_f1-score: 0.0122
# 5_support: 441.0000
# 6_precision: 0.0000
# 6_recall: 0.0000
# 6_f1-score: 0.0000
# 6_support: 204.0000
# 7_precision: 0.0000
# 7_recall: 0.0000
# 7_f1-score: 0.0000
# 7_support: 196.0000
# 8_precision: 0.0000
# 8_recall: 0.0000
# 8_f1-score: 0.0000
# 8_support: 53.0000
# 9_precision: 0.0000
# 9_recall: 0.0000
# 9_f1-score: 0.0000
# 9_support: 11.0000
# 10_precision: 0.0000
# 10_recall: 0.0000
# 10_f1-score: 0.0000
# 10_support: 6.0000
# 11_precision: 0.0000
# 11_recall: 0.0000
# 11_f1-score: 0.0000
# 11_support: 4.0000
# 12_precision: 0.0000
# 12_recall: 0.0000
# 12_f1-score: 0.0000
# 12_support: 4.0000
# 13_precision: 0.0000
# 13_recall: 0.0000
# 13_f1-score: 0.0000
# 13_support: 2.0000
# 14_precision: 0.0000
# 14_recall: 0.0000
# 14_f1-score: 0.0000
# 14_support: 2.0000
# 15_precision: 0.0000
# 15_recall: 0.0000
# 15_f1-score: 0.0000
# 15_support: 2.0000
# 16_precision: 0.0000
# 16_recall: 0.0000
# 16_f1-score: 0.0000
# 16_support: 1.0000
# 17_precision: 0.0000
# 17_recall: 0.0000
# 17_f1-score: 0.0000
# 17_support: 2.0000
# 18_precision: 0.0000
# 18_recall: 0.0000
# 18_f1-score: 0.0000
# 18_support: 1.0000
# 19_precision: 0.0000
# 19_recall: 0.0000
# 19_f1-score: 0.0000
# 19_support: 1.0000
# 20_precision: 0.0000
# 20_recall: 0.0000
# 20_f1-score: 0.0000
# 20_support: 1.0000
# accuracy: 0.9609
# macro avg_precision: 0.1176
# macro avg_recall: 0.0736
# macro avg_f1-score: 0.0763
# macro avg_support: 203708.0000
# weighted avg_precision: 0.9344
# weighted avg_recall: 0.9609
# weighted avg_f1-score: 0.9437
# weighted avg_support: 203708.0000

# %% [markdown]
# # Darknet

# %%
labels_map = {
    'Normal': 0, 'Darknet_Audio-Streaming': 1, 'Darknet_Chat': 2, 'Darknet_File-Transfer': 3, 'Darknet_VOIP': 4,
    'Darknet_Video-Streaming': 5, 'Darknet_Email': 6, 'Darknet_Browsing': 7, 'Darknet_P2P': 8
}

run_model("darknet_train.csv", "darknet_test.csv", is_string_labels = True, label_mapping = labels_map)
# Out:
# Verbose output only for first run...
# Run 1/5 started...
# Epoch 1/1000
# 397/397 ━━━━━━━━━━━━━━━━━━━━ 20s 9ms/step - accuracy: 0
1000
# 397/397 ━━━━━━━━━━━━━━━━━━━━ 3s 7ms/step - accuracy: 0.8921 - loss: 0.3610 - val_accuracy: 0.8935 - val_loss: 0.3515
# Epoch 125/1000
# 397/397 ━━━━━━━━━━━━━━━━━━━━ 3s 7ms/step - accuracy: 0.8901 - loss: 0.3668 - val_accuracy: 0.8937 - val_loss: 0.3523
# Epoch 126/1000
# 397/397 ━━━━━━━━━━━━━━━━━━━━ 3s 7ms/step - accuracy: 0.8929 - loss: 0.3597 - val_accuracy: 0.8950 - val_loss: 0.3466
# Epoch 127/1000
# 397/397 ━━━━━━━━━━━━━━━━━━━━ 3s 7ms/step - accuracy: 0.8900 - loss: 0.3654 - val_accuracy: 0.8870 - val_loss: 0.3575
# Epoch 128/1000
# 397/397 ━━━━━━━━━━━━━━━━━━━━ 3s 7ms/step - accuracy: 0.8908 - loss: 0.3607 - val_accuracy: 0.8932 - val_loss: 0.3528
# Epoch 129/1000
# 397/397 ━━━━━━━━━━━━━━━━━━━━ 3s 7ms/step - accuracy: 0.8905 - loss: 0.3591 - val_accuracy: 0.8981 - val_loss: 0.3449
# Epoch 130/1000
# 397/397 ━━━━━━━━━━━━━━━━━━━━ 3s 7ms/step - accuracy: 0.8920 - loss: 0.3573 - val_accuracy: 0.8864 - val_loss: 0.3538
# Epoch 131/1000
# 397/397 ━━━━━━━━━━━━━━━━━━━━ 3s 7ms/step - accuracy: 0.8898 - loss: 0.3666 - val_accuracy: 0.8961 - val_loss: 0.3452
# Epoch 132/1000
# 397/397 ━━━━━━━━━━━━━━━━━━━━ 3s 7ms/step - accuracy: 0.8908 - loss: 0.3631 - val_accuracy: 0.8870 - val_loss: 0.3558
# Epoch 133/1000
# 397/397 ━━━━━━━━━━━━━━━━━━━━ 3s 7ms/step - accuracy: 0.8920 - loss: 0.3590 - val_accuracy: 0.8878 - val_loss: 0.3539
# Epoch 134/1000
# 397/397 ━━━━━━━━━━━━━━━━━━━━ 3s 7ms/step - accuracy: 0.8908 - loss: 0.3589 - val_accuracy: 0.8944 - val_loss: 0.3462
# Epoch 135/1000
# 397/397 ━━━━━━━━━━━━━━━━━━━━ 3s 7ms/step - accuracy: 0.8918 - loss: 0.3650 - val_accuracy: 0.8965 - val_loss: 0.3456
# Epoch 136/1000
# 397/397 ━━━━━━━━━━━━━━━━━━━━ 3s 7ms/step - accuracy: 0.8905 - loss: 0.3607 - val_accuracy: 0.8925 - val_loss: 0.3483
# Epoch 137/1000
# 397/397 ━━━━━━━━━━━━━━━━━━━━ 3s 7ms/step - accuracy: 0.8934 - loss: 0.3588 - val_accuracy: 0.8927 - val_loss: 0.3510
# Epoch 138/1000
# 397/397 ━━━━━━━━━━━━━━━━━━━━ 3s 7ms/step - accuracy: 0.8909 - loss: 0.3598 - val_accuracy: 0.8855 - val_loss: 0.3520
# Epoch 139/1000
# 397/397 ━━━━━━━━━━━━━━━━━━━━ 3s 7ms/step - accuracy: 0.8925 - loss: 0.3559 - val_accuracy: 0.8937 - val_loss: 0.3461
# Run 2/5 started...
# Run 3/5 started...
# Run 4/5 started...
# Run 5/5 started...
#
# Aggregated Metrics:
# test_loss: 0.4607
# test_accuracy: 0.8656
# roc_auc: 0.8110
# pr_auc: 0.8666
# f2: 0.8460
# mcc: 0.2680
# 0_precision: 0.8772
# 0_recall: 0.9877
# 0_f1-score: 0.9287
# 0_support: 26862.0000
# 1_precision: 0.4280
# 1_recall: 0.2909
# 1_f1-score: 0.3447
# 1_support: 2657.0000
# 2_precision: 0.0927
# 2_recall: 0.1489
# 2_f1-score: 0.1143
# 2_support: 908.0000
# 3_precision: 0.1169
# 3_recall: 0.0291
# 3_f1-score: 0.0466
# 3_support: 522.0000
# 4_precision: 0.0000
# 4_recall: 0.0000
# 4_f1-score: 0.0000
# 4_support: 293.0000
# 5_precision: 0.0000
# 5_recall: 0.0000
# 5_f1-score: 0.0000
# 5_support: 269.0000
# 6_precision: 0.0000
# 6_recall: 0.0000
# 6_f1-score: 0.0000
# 6_support: 116.0000
# 7_precision: 0.0000
# 7_recall: 0.0000
# 7_f1-score: 0.0000
# 7_support: 53.0000
# 8_precision: 0.1400
# 8_recall: 0.0955
# 8_f1-score: 0.1135
# 8_support: 44.0000
# accuracy: 0.8656
# macro avg_precision: 0.1839
# macro avg_recall: 0.1725
# macro avg_f1-score: 0.1720
# macro avg_support: 31724.0000
# weighted avg_precision: 0.7833
# weighted avg_recall: 0.8656
# weighted avg_f1-score: 0.8195
# weighted avg_support: 31724.0000
