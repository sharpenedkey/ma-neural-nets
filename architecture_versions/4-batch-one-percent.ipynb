# %%
import warnings
warnings.filterwarnings("ignore")

# %%
import numpy as np
import pandas as pd
import tensorflow as tf

from collections import defaultdict
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import OneHotEncoder
from sklearn.metrics import classification_report, balanced_accuracy_score, roc_auc_score, average_precision_score, fbeta_score, matthews_corrcoef
from tensorflow.keras.callbacks import EarlyStopping
from tensorflow.keras.models import Model
from tensorflow.keras.layers import Input, Dense, Dropout, Lambda, Concatenate

# %%
# Custom function to build hidden combination (i.e. convolution) layers

def create_random_combination_layer(input_layer, combination_size, num_combinations, input_dim):
    outputs = []
    
    for _ in range(num_combinations):
        # First random feature selection
        indices_1 = np.random.choice(input_dim, combination_size, replace=False)
        indices_tensor_1 = tf.constant(indices_1, dtype=tf.int32)
        
        # First feature selection using Lambda layer
        slice_layer_1 = Lambda(
            lambda x: tf.gather(x, indices_tensor_1, axis=1),  # Gather selected features
            output_shape=(combination_size,)
        )(input_layer)
        
        # Second random feature selection (after the first random selection)
        indices_2 = np.random.choice(combination_size, combination_size, replace=False)
        indices_tensor_2 = tf.constant(indices_2, dtype=tf.int32)
        
        # Second feature selection using Lambda layer
        slice_layer_2 = Lambda(
            lambda x: tf.gather(x, indices_tensor_2, axis=1),  # Apply a second feature selection
            output_shape=(combination_size,)
        )(slice_layer_1)

        # Apply Dense layers on the final selected subset
        selected_features = Dense(16, activation='relu')(
            Dense(8, activation='relu')(
                Dense(4, activation='relu')(slice_layer_2)
            )
        )
        outputs.append(selected_features)
    
    # Concatenate the outputs from all the random feature combinations
    return Concatenate()(outputs)

# %%
def run_model(train_data_path, test_data_path, is_string_labels = False, label_mapping = None):

    # Initialize the one-hot encoder for the target
    encoder = OneHotEncoder(sparse_output=False)

    # Load and Prepare Training Data
    train_data = pd.read_csv(train_data_path)
    train_data = train_data.sample(frac=1).reset_index(drop=True)  # Shuffle
    if (is_string_labels):
        train_data['label'] = train_data['label'].map(label_mapping)
    train_X = train_data.drop(columns=['label']).values
    train_y = train_data['label'].values
    train_y = encoder.fit_transform(train_y.reshape(-1, 1))

    # Perform a stratified split into train and validation sets (80% train, 20% validation)
    X_train, X_val, y_train, y_val = train_test_split(train_X, train_y, test_size=0.2, random_state=42, stratify=train_y)

    # Load and Prepare Test Data (this will not be used in training)
    test_data = pd.read_csv(test_data_path)
    test_data = test_data.sample(frac=1).reset_index(drop=True)  # Shuffle
    if (is_string_labels):
        test_data['label'] = test_data['label'].map(label_mapping)
    test_X = test_data.drop(columns=['label']).values
    test_y = test_data['label'].values
    test_y = encoder.transform(test_y.reshape(-1, 1))

    # Parameters for Random Feature Combination
    num_combinations = 20  # Number of random column combinations
    combination_size = 3   # Number of columns in each combination

    # Number of features and classes of the original dataset
    num_features = train_X.shape[1]
    num_classes = train_y.shape[1]

    # EarlyStopping Callback (optional, to avoid overfitting)
    early_stopping = EarlyStopping(monitor='val_loss', patience=10, restore_best_weights=True)

    # Number of runs for averaging results
    num_runs = 5

    # Initialize storage for metrics
    metrics_storage = defaultdict(list)

    # Train the Model with Validation Split N tines for more accurate metrics
    print("Verbose output only for first run...")
    verbose_run = 1
    for run in range(num_runs):
        
        # Model is defined separately in each run, since the random combination layers
        # must be randomly initialized each time. Otherwise, the "random" indices stay the same
        # throughout all runs
        input_layer = Input(shape=(X_train.shape[1],))  # Input shape from the training data
        feature_layer = create_random_combination_layer(input_layer, combination_size, num_combinations, X_train.shape[1])
        hidden_layer = Dense(128, activation='relu')(feature_layer)
        hidden_layer = Dropout(0.5)(hidden_layer)
        output_layer = Dense(test_y.shape[1], activation='softmax')(hidden_layer)
        model = Model(inputs=input_layer, outputs=output_layer)
        model.compile(optimizer='adam', loss='categorical_crossentropy', metrics=['accuracy'])

        print(f"Run {run + 1}/{num_runs} started...")
        history = model.fit(
            X_train, y_train, 
            epochs=1000, 
            batch_size=int(X_train.shape[0] * 0.01), 
            validation_data=(X_val, y_val),
            callbacks=[early_stopping],
            verbose=verbose_run
        )
        verbose_run = 0 # Suppress detailed output for multiple runs

        test_loss, test_acc = model.evaluate(test_X, test_y, verbose=0)
        y_pred = model.predict(test_X, verbose=0)
        y_pred_classes = y_pred.argmax(axis=1)
        y_true_classes = test_y.argmax(axis=1)

        # Compute metrics
        balanced_acc = balanced_accuracy_score(test_y, y_pred)
        roc_auc = roc_auc_score(test_y, y_pred, multi_class='ovr')
        pr_auc = average_precision_score(test_y, y_pred, average='weighted')
        f2 = fbeta_score(y_true_classes, y_pred_classes, beta=2, average='weighted')
        mcc = matthews_corrcoef(y_true_classes, y_pred_classes)

        # Store metrics
        metrics_storage['test_loss'].append(test_loss)
        metrics_storage['test_accuracy'].append(test_acc)
        metrics_storage['balanced_accuracy'].append(balanced_acc)
        metrics_storage['roc_auc'].append(roc_auc)
        metrics_storage['pr_auc'].append(pr_auc)
        metrics_storage['f2'].append(f2)
        metrics_storage['mcc'].append(mcc)

        # Store classification report metrics
        report = classification_report(y_true_classes, y_pred_classes, output_dict=True)
        for label, values in report.items():
            # Check if the value is a dictionary (e.g., 'precision', 'recall', 'f1-score')
            if isinstance(values, dict):
                for metric, value in values.items():
                    metrics_storage[f"{label}_{metric}"].append(value)
            else:
                # Handle scalar values (like 'accuracy')
                metrics_storage[label].append(values)

    # Average the metrics over all runs
    print("\nAggregated Metrics:")
    for metric, values in metrics_storage.items():
        avg_value = np.mean(values)
        print(f"{metric}: {avg_value:.4f}")

# %% [markdown]
# # Shuttle

# %%
run_model("shuttle_train.csv", "shuttle_test.csv", is_string_labels = False)
# Out:
# Verbose output only for first run...
# Run 1/5 started...
# Epoch 1/1000
# 101/101 ━━━━━━━━━━━━━━━━━━━━ 19s 15ms/step - accuracy: 0.7615 - loss: 0.9431 - val_accuracy: 0.9281 - val_loss: 0.2515
# Epoch 2/1000
# 101/101 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - accuracy: 0.9240 - loss: 0.2373 - val_accuracy: 0.9355 - val_loss: 0.1843
# Epoch 3/1000
# 101/101 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - accuracy: 0.9298 - loss: 0.1819 - val_accuracy: 0.9364 - val_loss: 0.1662
# Epoch 4/1000
# 101/101 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - accuracy: 0.9327 - loss: 0.1735 - val_accuracy: 0.9386 - val_loss: 0.1689
# Epoch 5/1000
# 101/101 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - accuracy: 0.9376 - loss: 0.1555 - val_accuracy: 0.9457 - val_loss: 0.1554
# Epoch 6/1000
# 101/101 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - accuracy: 0.9415 - loss: 0.1470 - val_accuracy: 0.9489 - val_loss: 0.1488
# Epoch 7/1000
# 101/101 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - accuracy: 0.9465 - loss: 0.1401 - val_accuracy: 0.9554 - val_loss: 0.1500
# Epoch 8/1000
# 101/101 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - accuracy: 0.9497 - loss: 0.1279 - val_accuracy: 0.9538 - val_loss: 0.1526
# Epoch 9/1000
# 101/101 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - accuracy: 0.9538 - loss: 0.1201 - val_accuracy: 0.9555 - val_loss: 0.1462
# Epoch 10/1000
# 101/101 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - accuracy: 0.9539 - loss: 0.1225 - val_accuracy: 0.9594 - val_loss: 0.1420
# Epoch 11/1000
# 101/101 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - accuracy: 0.9572 - loss: 0.1411 - val_accuracy: 0.9593 - val_loss: 0.1432
# Epoch 12/1000
# 101/101 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - accuracy: 0.9586 - loss: 0.1092 - val_accuracy: 0.9613 - val_loss: 0.1446
# Epoch 13/1000
# 101/101 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - accuracy: 0.9579 - loss: 0.1104 - val_accuracy: 0.9619 - val_loss: 0.1500
# Epoch 14/1000
# 101/101 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - accuracy: 0.9597 - loss: 0.1063 - val_accuracy: 0.9620 - val_loss: 0.1510
# Epoch 15/1000
# 101/101 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - accuracy: 0.9567 - loss: 0.1055 - val_accuracy: 0.9650 - val_loss: 0.1502
# Epoch 16/1000
# 101/101 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - accuracy: 0.9589 - loss: 0.1098 - val_accuracy: 0.9595 - val_loss: 0.1537
# Epoch 17/1000
# 101/101 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - accuracy: 0.9595 - loss: 0.1040 - val_accuracy: 0.9642 - val_loss: 0.1500
# Epoch 18/1000
# 101/101 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - accuracy: 0.9605 - loss: 0.1010 - val_accuracy: 0.9626 - val_loss: 0.1504
# Epoch 19/1000
# 101/101 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - accuracy: 0.9636 - loss: 0.0976 - val_accuracy: 0.9627 - val_loss: 0.1541
# Epoch 20/1000
# 101/101 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - accuracy: 0.9596 - loss: 0.1055 - val_accuracy: 0.9648 - val_loss: 0.1537
# Run 2/5 started...
# Run 3/5 started...
# Run 4/5 started...
# Run 5/5 started...
#
# Aggregated Metrics:
# test_loss: 0.1549
# test_accuracy: 0.9538
# roc_auc: 0.8406
# pr_auc: 0.9668
# f2: 0.9515
# mcc: 0.8673
# 0_precision: 0.9671
# 0_recall: 0.9783
# 0_f1-score: 0.9721
# 0_support: 9117.0000
# 1_precision: 0.3667
# 1_recall: 0.2600
# 1_f1-score: 0.2741
# 1_support: 10.0000
# 2_precision: 0.4000
# 2_recall: 0.1529
# 2_f1-score: 0.2147
# 2_support: 34.0000
# 3_precision: 0.8801
# 3_recall: 0.8347
# 3_f1-score: 0.8378
# 3_support: 1781.0000
# 4_precision: 0.9887
# 4_recall: 0.9948
# 4_f1-score: 0.9917
# 4_support: 653.0000
# 5_precision: 0.0000
# 5_recall: 0.0000
# 5_f1-score: 0.0000
# 5_support: 2.0000
# 6_precision: 0.0000
# 6_recall: 0.0000
# 6_f1-score: 0.0000
# 6_support: 3.0000
# accuracy: 0.9538
# macro avg_precision: 0.5147
# macro avg_recall: 0.4601
# macro avg_f1-score: 0.4701
# macro avg_support: 11600.0000
# weighted avg_precision: 0.9524
# weighted avg_recall: 0.9538
# weighted avg_f1-score: 0.9494
# weighted avg_support: 11600.0000

# %% [markdown]
# # Covertype

# %%
run_model("covtype_train.csv", "covtype_test.csv", is_string_labels = False)
# Out:
# Verbose output only for first run...
# Run 1/5 started...
# Epoch 1/1000
# 101/101 ━━━━━━━━━━━━━━━━━━━━ 21s 35ms/step - accuracy: 0.4700 - loss: 1.5979 - val_accuracy: 0.4876 - val_loss: 1.1845
# Epoch 2/1000
# 101/101 ━━━━━━━━━━━━━━━━━━━━ 3s 27ms/step - accuracy: 0.4752 - loss: 1.2082 - val_accuracy: 0.4876 - val_loss: 1.1819
# Epoch 3/1000
# 101/101 ━━━━━━━━━━━━━━━━━━━━ 3s 27ms/step - accuracy: 0.4842 - loss: 1.1968 - val_accuracy: 0.4876 - val_loss: 1.1811
# Epoch 4/1000
# 101/101 ━━━━━━━━━━━━━━━━━━━━ 3s 27ms/step - accuracy: 0.4874 - loss: 1.1944 - val_accuracy: 0.4876 - val_loss: 1.1816
# Epoch 5/1000
# 101/101 ━━━━━━━━━━━━━━━━━━━━ 3s 29ms/step - accuracy: 0.4878 - loss: 1.1960 - val_accuracy: 0.4876 - val_loss: 1.1808
# Epoch 6/1000
# 101/101 ━━━━━━━━━━━━━━━━━━━━ 3s 27ms/step - accuracy: 0.4883 - loss: 1.1938 - val_accuracy: 0.4876 - val_loss: 1.1807
# Epoch 7/1000
# 101/101 ━━━━━━━━━━━━━━━━━━━━ 3s 27ms/step - accuracy: 0.4879 - loss: 1.1927 - val_accuracy: 0.4876 - val_loss: 1.1807
# Epoch 8/1000
# 101/101 ━━━━━━━━━━━━━━━━━━━━ 3s 27ms/step - accuracy: 0.4866 - loss: 1.1938 - val_accuracy: 0.4876 - val_loss: 1.1809
# Epoch 9/1000
# 101/101 ━━━━━━━━━━━━━━━━━━━━ 3s 28ms/step - accuracy: 0.4880 - loss: 1.1910 - val_accuracy: 0.4876 - val_loss: 1.1804
# Epoch 10/1000
# 101/101 ━━━━━━━━━━━━━━━━━━━━ 3s 27ms/step - accuracy: 0.4867 - loss: 1.1915 - val_accuracy: 0.4876 - val_loss: 1.1807
# Epoch 11/1000
# 101/101 ━━━━━━━━━━━━━━━━━━━━ 3s 27ms/step - accuracy: 0.4887 - loss: 1.1909 - val_accuracy: 0.4876 - val_loss: 1.1807
# Epoch 12/1000
# 101/101 ━━━━━━━━━━━━━━━━━━━━ 3s 27ms/step - accuracy: 0.4861 - loss: 1.1927 - val_accuracy: 0.4876 - val_loss: 1.1807
# Epoch 13/1000
# 101/101 ━━━━━━━━━━━━━━━━━━━━ 3s 29ms/step - accuracy: 0.4869 - loss: 1.1907 - val_accuracy: 0.4876 - val_loss: 1.1804
# Epoch 14/1000
# 101/101 ━━━━━━━━━━━━━━━━━━━━ 3s 27ms/step - accuracy: 0.4875 - loss: 1.1917 - val_accuracy: 0.4876 - val_loss: 1.1804
# Epoch 15/1000
# 101/101 ━━━━━━━━━━━━━━━━━━━━ 3s 27ms/step - accuracy: 0.4878 - loss: 1.1914 - val_accuracy: 0.4876 - val_loss: 1.1804
# Epoch 16/1000
# 101/101 ━━━━━━━━━━━━━━━━━━━━ 3s 27ms/step - accuracy: 0.4875 - loss: 1.1918 - val_accuracy: 0.4876 - val_loss: 1.1805
# Epoch 17/1000
# 101/101 ━━━━━━━━━━━━━━━━━━━━ 3s 27ms/step - accuracy: 0.4880 - loss: 1.1897 - val_accuracy: 0.4876 - val_loss: 1.1809
# Epoch 18/1000
# 101/101 ━━━━━━━━━━━━━━━━━━━━ 3s 27ms/step - accuracy: 0.4878 - loss: 1.1880 - val_accuracy: 0.4876 - val_loss: 1.1804
# Epoch 19/1000
# 101/101 ━━━━━━━━━━━━━━━━━━━━ 3s 27ms/step - accuracy: 0.4868 - loss: 1.1914 - val_accuracy: 0.4876 - val_loss: 1.1804
# Epoch 20/1000
# 101/101 ━━━━━━━━━━━━━━━━━━━━ 3s 27ms/step - accuracy: 0.4874 - loss: 1.1898 - val_accuracy: 0.4876 - val_loss: 1.1805
# Epoch 21/1000
# 101/101 ━━━━━━━━━━━━━━━━━━━━ 3s 27ms/step - accuracy: 0.4895 - loss: 1.1864 - val_accuracy: 0.4876 - val_loss: 1.1804
# Epoch 22/1000
# 101/101 ━━━━━━━━━━━━━━━━━━━━ 3s 29ms/step - accuracy: 0.4881 - loss: 1.1898 - val_accuracy: 0.4876 - val_loss: 1.1807
# Epoch 23/1000
# 101/101 ━━━━━━━━━━━━━━━━━━━━ 3s 30ms/step - accuracy: 0.4869 - loss: 1.1924 - val_accuracy: 0.4876 - val_loss: 1.1803
# Epoch 24/1000
# 101/101 ━━━━━━━━━━━━━━━━━━━━ 3s 27ms/step - accuracy: 0.4885 - loss: 1.1907 - val_accuracy: 0.4876 - val_loss: 1.1807
# Epoch 25/1000
# 101/101 ━━━━━━━━━━━━━━━━━━━━ 3s 27ms/step - accuracy: 0.4877 - loss: 1.1892 - val_accuracy: 0.4876 - val_loss: 1.1804
# Epoch 26/1000
# 101/101 ━━━━━━━━━━━━━━━━━━━━ 3s 27ms/step - accuracy: 0.4884 - loss: 1.1882 - val_accuracy: 0.4876 - val_loss: 1.1804
# Epoch 27/1000
# 101/101 ━━━━━━━━━━━━━━━━━━━━ 3s 27ms/step - accuracy: 0.4868 - loss: 1.1906 - val_accuracy: 0.4876 - val_loss: 1.1804
# Epoch 28/1000
# 101/101 ━━━━━━━━━━━━━━━━━━━━ 3s 27ms/step - accuracy: 0.4876 - loss: 1.1881 - val_accuracy: 0.4876 - val_loss: 1.1804
# Epoch 29/1000
# 101/101 ━━━━━━━━━━━━━━━━━━━━ 3s 30ms/step - accuracy: 0.4870 - loss: 1.1883 - val_accuracy: 0.4876 - val_loss: 1.1805
# Epoch 30/1000
# 101/101 ━━━━━━━━━━━━━━━━━━━━ 3s 28ms/step - accuracy: 0.4889 - loss: 1.1840 - val_accuracy: 0.4876 - val_loss: 1.1804
# Epoch 31/1000
# 101/101 ━━━━━━━━━━━━━━━━━━━━ 3s 28ms/step - accuracy: 0.4888 - loss: 1.1867 - val_accuracy: 0.4876 - val_loss: 1.1805
# Epoch 32/1000
# 101/101 ━━━━━━━━━━━━━━━━━━━━ 3s 29ms/step - accuracy: 0.4880 - loss: 1.1861 - val_accuracy: 0.4876 - val_loss: 1.1805
# Epoch 33/1000
# 101/101 ━━━━━━━━━━━━━━━━━━━━ 3s 27ms/step - accuracy: 0.4878 - loss: 1.1862 - val_accuracy: 0.4876 - val_loss: 1.1809
# Run 2/5 started...
# Run 3/5 started...
# Run 4/5 started...
# Run 5/5 started...
#
# Aggregated Metrics:
# test_loss: 0.9786
# test_accuracy: 0.5685
# roc_auc: 0.7286
# pr_auc: 0.5329
# f2: 0.5184
# mcc: 0.2114
# 0_precision: 0.3699
# 0_recall: 0.2958
# 0_f1-score: 0.3063
# 0_support: 42368.0000
# 1_precision: 0.5795
# 1_recall: 0.9034
# 1_f1-score: 0.6919
# 1_support: 56661.0000
# 2_precision: 0.2257
# 2_recall: 0.2762
# 2_f1-score: 0.2484
# 2_support: 7151.0000
# 3_precision: 0.0857
# 3_recall: 0.0011
# 3_f1-score: 0.0022
# 3_support: 549.0000
# 4_precision: 0.1404
# 4_recall: 0.0340
# 4_f1-score: 0.0548
# 4_support: 1899.0000
# 5_precision: 0.1443
# 5_recall: 0.0051
# 5_f1-score: 0.0098
# 5_support: 3473.0000
# 6_precision: 0.4838
# 6_recall: 0.0703
# 6_f1-score: 0.1130
# 6_support: 4102.0000
# accuracy: 0.5685
# macro avg_precision: 0.2899
# macro avg_recall: 0.2265
# macro avg_f1-score: 0.2038
# macro avg_support: 116203.0000
# weighted avg_precision: 0.4554
# weighted avg_recall: 0.5685
# weighted avg_f1-score: 0.4695
# weighted avg_support: 116203.0000

# %% [markdown]
# # KDD

# %%
labels_map = {
    'normal.': 0, 'satan.': 1, 'ipsweep.': 2, 'portsweep.': 3, 'nmap.': 4,
    'back.': 5, 'warezclient.': 6, 'teardrop.': 7, 'pod.': 8, 'guess_passwd.': 9,
    'buffer_overflow.': 10, 'land.': 11, 'warezmaster.': 12, 'imap.': 13, 'rootkit.': 14,
    'loadmodule.': 15, 'multihop.': 16, 'ftp_write.': 17, 'phf.': 18, 'perl.': 19, 'spy.': 20
}

run_model("kdd_train.csv", "kdd_test.csv", is_string_labels = True, label_mapping = labels_map)
# Out:
# Verbose output only for first run...
# Run 1/5 started...
# Epoch 1/1000
# 101/101 ━━━━━━━━━━━━━━━━━━━━ 24s 57ms/step - accuracy: 0.9062 - loss: 1.8089 - val_accuracy: 0.9551 - val_loss: 0.2642
# Epoch 2/1000
# 101/101 ━━━━━━━━━━━━━━━━━━━━ 5s 51ms/step - accuracy: 0.9551 - loss: 0.2912 - val_accuracy: 0.9551 - val_loss: 0.2583
# Epoch 3/1000
# 101/101 ━━━━━━━━━━━━━━━━━━━━ 5s 52ms/step - accuracy: 0.9547 - loss: 0.2795 - val_accuracy: 0.9551 - val_loss: 0.2558
# Epoch 4/1000
# 101/101 ━━━━━━━━━━━━━━━━━━━━ 5s 50ms/step - accuracy: 0.9550 - loss: 0.2709 - val_accuracy: 0.9550 - val_loss: 0.2549
# Epoch 5/1000
# 101/101 ━━━━━━━━━━━━━━━━━━━━ 5s 52ms/step - accuracy: 0.9549 - loss: 0.2664 - val_accuracy: 0.9551 - val_loss: 0.2541
# Epoch 6/1000
# 101/101 ━━━━━━━━━━━━━━━━━━━━ 5s 52ms/step - accuracy: 0.9550 - loss: 0.2646 - val_accuracy: 0.9549 - val_loss: 0.2536
# Epoch 7/1000
# 101/101 ━━━━━━━━━━━━━━━━━━━━ 5s 48ms/step - accuracy: 0.9547 - loss: 0.2653 - val_accuracy: 0.9551 - val_loss: 0.2529
# Epoch 8/1000
# 101/101 ━━━━━━━━━━━━━━━━━━━━ 5s 48ms/step - accuracy: 0.9555 - loss: 0.2607 - val_accuracy: 0.9551 - val_loss: 0.2518
# Epoch 9/1000
# 101/101 ━━━━━━━━━━━━━━━━━━━━ 5s 48ms/step - accuracy: 0.9552 - loss: 0.2602 - val_accuracy: 0.9551 - val_loss: 0.2517
# Epoch 10/1000
# 101/101 ━━━━━━━━━━━━━━━━━━━━ 5s 49ms/step - accuracy: 0.9550 - loss: 0.2607 - val_accuracy: 0.9551 - val_loss: 0.2508
# Epoch 11/1000
# 101/101 ━━━━━━━━━━━━━━━━━━━━ 5s 48ms/step - accuracy: 0.9555 - loss: 0.2570 - val_accuracy: 0.9551 - val_loss: 0.2498
# Epoch 12/1000
# 101/101 ━━━━━━━━━━━━━━━━━━━━ 5s 49ms/step - accuracy: 0.9550 - loss: 0.2568 - val_accuracy: 0.9551 - val_loss: 0.2476
# Epoch 13/1000
# 101/101 ━━━━━━━━━━━━━━━━━━━━ 5s 49ms/step - accuracy: 0.9549 - loss: 0.2574 - val_accuracy: 0.9551 - val_loss: 0.2476
# Epoch 14/1000
# 101/101 ━━━━━━━━━━━━━━━━━━━━ 5s 48ms/step - accuracy: 0.9554 - loss: 0.2524 - val_accuracy: 0.9551 - val_loss: 0.2446
# Epoch 15/1000
# 101/101 ━━━━━━━━━━━━━━━━━━━━ 5s 48ms/step - accuracy: 0.9550 - loss: 0.2525 - val_accuracy: 0.9550 - val_loss: 0.2420
# Epoch 16/1000
# 101/101 ━━━━━━━━━━━━━━━━━━━━ 5s 49ms/step - accuracy: 0.9551 - loss: 0.2491 - val_accuracy: 0.9551 - val_loss: 0.2411
# Epoch 17/1000
# 101/101 ━━━━━━━━━━━━━━━━━━━━ 5s 48ms/step - accuracy: 0.9551 - loss: 0.2458 - val_accuracy: 0.9550 - val_loss: 0.2347
# Epoch 18/1000
# 101/101 ━━━━━━━━━━━━━━━━━━━━ 5s 48ms/step - accuracy: 0.9553 - loss: 0.2409 - val_accuracy: 0.9550 - val_loss: 0.2298
# Epoch 19/1000
# 101/101 ━━━━━━━━━━━━━━━━━━━━ 5s 49ms/step - accuracy: 0.9547 - loss: 0.2384 - val_accuracy: 0.9550 - val_loss: 0.2320
# Epoch 20/1000
# 101/101 ━━━━━━━━━━━━━━━━━━━━ 5s 49ms/step - accuracy: 0.9549 - loss: 0.2357 - val_accuracy: 0.9551 - val_loss: 0.2237
# Epoch 21/1000
# 101/101 ━━━━━━━━━━━━━━━━━━━━ 5s 49ms/step - accuracy: 0
1000
# 101/101 ━━━━━━━━━━━━━━━━━━━━ 5s 50ms/step - accuracy: 0.9551 - loss: 0.2012 - val_accuracy: 0.9551 - val_loss: 0.1821
# Epoch 54/1000
# 101/101 ━━━━━━━━━━━━━━━━━━━━ 5s 50ms/step - accuracy: 0.9555 - loss: 0.1881 - val_accuracy: 0.9551 - val_loss: 0.1855
# Epoch 55/1000
# 101/101 ━━━━━━━━━━━━━━━━━━━━ 5s 50ms/step - accuracy: 0.9552 - loss: 0.1892 - val_accuracy: 0.9551 - val_loss: 0.1957
# Epoch 56/1000
# 101/101 ━━━━━━━━━━━━━━━━━━━━ 5s 50ms/step - accuracy: 0.9549 - loss: 0.1896 - val_accuracy: 0.9551 - val_loss: 0.1828
# Epoch 57/1000
# 101/101 ━━━━━━━━━━━━━━━━━━━━ 5s 50ms/step - accuracy: 0.9549 - loss: 0.1857 - val_accuracy: 0.9551 - val_loss: 0.1811
# Epoch 58/1000
# 101/101 ━━━━━━━━━━━━━━━━━━━━ 5s 50ms/step - accuracy: 0.9548 - loss: 0.1853 - val_accuracy: 0.9551 - val_loss: 0.2023
# Epoch 59/1000
# 101/101 ━━━━━━━━━━━━━━━━━━━━ 5s 50ms/step - accuracy: 0.9553 - loss: 0.1914 - val_accuracy: 0.9551 - val_loss: 0.1835
# Epoch 60/1000
# 101/101 ━━━━━━━━━━━━━━━━━━━━ 5s 50ms/step - accuracy: 0.9549 - loss: 0.1864 - val_accuracy: 0.9551 - val_loss: 0.1853
# Epoch 61/1000
# 101/101 ━━━━━━━━━━━━━━━━━━━━ 5s 50ms/step - accuracy: 0.9549 - loss: 0.1873 - val_accuracy: 0.9551 - val_loss: 0.2057
# Epoch 62/1000
# 101/101 ━━━━━━━━━━━━━━━━━━━━ 5s 51ms/step - accuracy: 0.9552 - loss: 0.1916 - val_accuracy: 0.9551 - val_loss: 0.1780
# Epoch 63/1000
# 101/101 ━━━━━━━━━━━━━━━━━━━━ 5s 50ms/step - accuracy: 0.9553 - loss: 0.1821 - val_accuracy: 0.9551 - val_loss: 0.1824
# Epoch 64/1000
# 101/101 ━━━━━━━━━━━━━━━━━━━━ 5s 50ms/step - accuracy: 0.9551 - loss: 0.1842 - val_accuracy: 0.9551 - val_loss: 0.2873
# Epoch 65/1000
# 101/101 ━━━━━━━━━━━━━━━━━━━━ 5s 51ms/step - accuracy: 0.9549 - loss: 0.2054 - val_accuracy: 0.9551 - val_loss: 0.2112
# Epoch 66/1000
# 101/101 ━━━━━━━━━━━━━━━━━━━━ 5s 50ms/step - accuracy: 0.9549 - loss: 0.2012 - val_accuracy: 0.9551 - val_loss: 0.2396
# Epoch 67/1000
# 101/101 ━━━━━━━━━━━━━━━━━━━━ 5s 50ms/step - accuracy: 0.9551 - loss: 0.1979 - val_accuracy: 0.9551 - val_loss: 0.1929
# Epoch 68/1000
# 101/101 ━━━━━━━━━━━━━━━━━━━━ 5s 50ms/step - accuracy: 0.9554 - loss: 0.1852 - val_accuracy: 0.9551 - val_loss: 0.1838
# Epoch 69/1000
# 101/101 ━━━━━━━━━━━━━━━━━━━━ 5s 50ms/step - accuracy: 0.9549 - loss: 0.1845 - val_accuracy: 0.9551 - val_loss: 0.1859
# Epoch 70/1000
# 101/101 ━━━━━━━━━━━━━━━━━━━━ 5s 50ms/step - accuracy: 0.9551 - loss: 0.1864 - val_accuracy: 0.9551 - val_loss: 0.2207
# Epoch 71/1000
# 101/101 ━━━━━━━━━━━━━━━━━━━━ 5s 50ms/step - accuracy: 0.9554 - loss: 0.1978 - val_accuracy: 0.9551 - val_loss: 0.2315
# Epoch 72/1000
# 101/101 ━━━━━━━━━━━━━━━━━━━━ 5s 50ms/step - accuracy: 0.9551 - loss: 0.1917 - val_accuracy: 0.9551 - val_loss: 0.1899
# Run 2/5 started...
# Run 3/5 started...
# Run 4/5 started...
# Run 5/5 started...
#
# Aggregated Metrics:
# test_loss: 0.1997
# test_accuracy: 0.9590
# roc_auc: 0.6146
# pr_auc: 0.9269
# f2: 0.9512
# mcc: 0.1373
# 0_precision: 0.9606
# 0_recall: 0.9988
# 0_f1-score: 0.9793
# 0_support: 194557.0000
# 1_precision: 0.1436
# 1_recall: 0.1836
# 1_f1-score: 0.1611
# 1_support: 3178.0000
# 2_precision: 0.1602
# 2_recall: 0.1775
# 2_f1-score: 0.1684
# 2_support: 2496.0000
# 3_precision: 0.0286
# 3_recall: 0.0001
# 3_f1-score: 0.0002
# 3_support: 2083.0000
# 4_precision: 0.0000
# 4_recall: 0.0000
# 4_f1-score: 0.0000
# 4_support: 463.0000
# 5_precision: 0.0000
# 5_recall: 0.0000
# 5_f1-score: 0.0000
# 5_support: 441.0000
# 6_precision: 0.0000
# 6_recall: 0.0000
# 6_f1-score: 0.0000
# 6_support: 204.0000
# 7_precision: 0.0000
# 7_recall: 0.0000
# 7_f1-score: 0.0000
# 7_support: 196.0000
# 8_precision: 0.0000
# 8_recall: 0.0000
# 8_f1-score: 0.0000
# 8_support: 53.0000
# 9_precision: 0.0000
# 9_recall: 0.0000
# 9_f1-score: 0.0000
# 9_support: 11.0000
# 10_precision: 0.0000
# 10_recall: 0.0000
# 10_f1-score: 0.0000
# 10_support: 6.0000
# 11_precision: 0.0000
# 11_recall: 0.0000
# 11_f1-score: 0.0000
# 11_support: 4.0000
# 12_precision: 0.0000
# 12_recall: 0.0000
# 12_f1-score: 0.0000
# 12_support: 4.0000
# 13_precision: 0.0000
# 13_recall: 0.0000
# 13_f1-score: 0.0000
# 13_support: 2.0000
# 14_precision: 0.0000
# 14_recall: 0.0000
# 14_f1-score: 0.0000
# 14_support: 2.0000
# 15_precision: 0.0000
# 15_recall: 0.0000
# 15_f1-score: 0.0000
# 15_support: 2.0000
# 16_precision: 0.0000
# 16_recall: 0.0000
# 16_f1-score: 0.0000
# 16_support: 1.0000
# 17_precision: 0.0000
# 17_recall: 0.0000
# 17_f1-score: 0.0000
# 17_support: 2.0000
# 18_precision: 0.0000
# 18_recall: 0.0000
# 18_f1-score: 0.0000
# 18_support: 1.0000
# 19_precision: 0.0000
# 19_recall: 0.0000
# 19_f1-score: 0.0000
# 19_support: 1.0000
# 20_precision: 0.0000
# 20_recall: 0.0000
# 20_f1-score: 0.0000
# 20_support: 1.0000
# accuracy: 0.9590
# macro avg_precision: 0.0616
# macro avg_recall: 0.0648
# macro avg_f1-score: 0.0623
# macro avg_support: 203708.0000
# weighted avg_precision: 0.9219
# weighted avg_recall: 0.9590
# weighted avg_f1-score: 0.9399
# weighted avg_support: 203708.0000

# %% [markdown]
# # Darknet

# %%
labels_map = {
    'Normal': 0, 'Darknet_Audio-Streaming': 1, 'Darknet_Chat': 2, 'Darknet_File-Transfer': 3, 'Darknet_VOIP': 4,
    'Darknet_Video-Streaming': 5, 'Darknet_Email': 6, 'Darknet_Browsing': 7, 'Darknet_P2P': 8
}

run_model("darknet_train.csv", "darknet_test.csv", is_string_labels = True, label_mapping = labels_map)
# Out:
# Verbose output only for first run...
# Run 1/5 started...
# Epoch 1/1000
# 101/101 ━━━━━━━━━━━━━━━━━━━━ 18s 18ms/step - accuracy: 0.7831 - loss: 0.9809 - val_accuracy: 0.8720 - val_loss: 0.4414
# Epoch 2/1000
# 101/101 ━━━━━━━━━━━━━━━━━━━━ 1s 12ms/step - accuracy: 0.8636 - loss: 0.4506 - val_accuracy: 0.8752 - val_loss: 0.4070
# Epoch 3/1000
# 101/101 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - accuracy: 0.8711 - loss: 0.4217 - val_accuracy: 0.8754 - val_loss: 0.3963
# Epoch 4/1000
# 101/101 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - accuracy: 0.8728 - loss: 0.4134 - val_accuracy: 0.8744 - val_loss: 0.3897
# Epoch 5/1000
# 101/101 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - accuracy: 0.8726 - loss: 0.4046 - val_accuracy: 0.8734 - val_loss: 0.3855
# Epoch 6/1000
# 101/101 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - accuracy: 0.8749 - loss: 0.3988 - val_accuracy: 0.8771 - val_loss: 0.3836
# Epoch 7/1000
# 101/101 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - accuracy: 0.8754 - loss: 0.3931 - val_accuracy: 0.8747 - val_loss: 0.3795
# Epoch 8/1000
# 101/101 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - accuracy: 0.8729 - loss: 0.3932 - val_accuracy: 0.8760 - val_loss: 0.3763
# Epoch 9/1000
# 101/101 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - accuracy: 0.8753 - loss: 0.3854 - val_accuracy: 0.8751 - val_loss: 0.3731
# Epoch 10/1000
# 101/101 ━━━━━━━━━━━━━━━━━━━━ 1s 12ms/step - accuracy: 0.8738 - loss: 0.3866 - val_accuracy: 0.8763 - val_loss: 0.3714
# Epoch 11/1000
# 101/101 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - accuracy: 0.8776 - loss: 0.3785 - val_accuracy: 0.8789 - val_loss: 0.3717
# Epoch 12/1000
# 101/101 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - accuracy: 0.8736 - loss: 0.3870 - val_accuracy: 0.8788 - val_loss: 0.3701
# Epoch 13/1000
# 101/101 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - accuracy: 0.
1000
# 101/101 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - accuracy: 0.8894 - loss: 0.3206 - val_accuracy: 0.8890 - val_loss: 0.3158
# Epoch 145/1000
# 101/101 ━━━━━━━━━━━━━━━━━━━━ 1s 12ms/step - accuracy: 0.8890 - loss: 0.3200 - val_accuracy: 0.8894 - val_loss: 0.3169
# Epoch 146/1000
# 101/101 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - accuracy: 0.8873 - loss: 0.3273 - val_accuracy: 0.8910 - val_loss: 0.3173
# Epoch 147/1000
# 101/101 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - accuracy: 0.8865 - loss: 0.3276 - val_accuracy: 0.8886 - val_loss: 0.3167
# Epoch 148/1000
# 101/101 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - accuracy: 0.8846 - loss: 0.3273 - val_accuracy: 0.8885 - val_loss: 0.3167
# Epoch 149/1000
# 101/101 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - accuracy: 0.8897 - loss: 0.3203 - val_accuracy: 0.8899 - val_loss: 0.3174
# Epoch 150/1000
# 101/101 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - accuracy: 0.8878 - loss: 0.3223 - val_accuracy: 0.8888 - val_loss: 0.3151
# Epoch 151/1000
# 101/101 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - accuracy: 0.8892 - loss: 0.3189 - val_accuracy: 0.8886 - val_loss: 0.3183
# Epoch 152/1000
# 101/101 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - accuracy: 0.8873 - loss: 0.3251 - val_accuracy: 0.8883 - val_loss: 0.3167
# Epoch 153/1000
# 101/101 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - accuracy: 0.8881 - loss: 0.3216 - val_accuracy: 0.8897 - val_loss: 0.3176
# Epoch 154/1000
# 101/101 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - accuracy: 0.8886 - loss: 0.3185 - val_accuracy: 0.8864 - val_loss: 0.3175
# Epoch 155/1000
# 101/101 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - accuracy: 0.8863 - loss: 0.3267 - val_accuracy: 0.8885 - val_loss: 0.3153
# Epoch 156/1000
# 101/101 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - accuracy: 0.8881 - loss: 0.3183 - val_accuracy: 0.8893 - val_loss: 0.3162
# Epoch 157/1000
# 101/101 ━━━━━━━━━━━━━━━━━━━━ 1s 12ms/step - accuracy: 0.8843 - loss: 0.3268 - val_accuracy: 0.8892 - val_loss: 0.3174
# Epoch 158/1000
# 101/101 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - accuracy: 0.8877 - loss: 0.3258 - val_accuracy: 0.8900 - val_loss: 0.3159
# Epoch 159/1000
# 101/101 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - accuracy: 0.8883 - loss: 0.3231 - val_accuracy: 0.8910 - val_loss: 0.3189
# Epoch 160/1000
# 101/101 ━━━━━━━━━━━━━━━━━━━━ 1s 12ms/step - accuracy: 0.8869 - loss: 0.3249 - val_accuracy: 0.8877 - val_loss: 0.3161
# Run 2/5 started...
# Run 3/5 started...
# Run 4/5 started...
# Run 5/5 started...
#
# Aggregated Metrics:
# test_loss: 0.4090
# test_accuracy: 0.8910
# roc_auc: 0.7929
# pr_auc: 0.8759
# f2: 0.8755
# mcc: 0.4421
# 0_precision: 0.8986
# 0_recall: 0.9911
# 0_f1-score: 0.9418
# 0_support: 26862.0000
# 1_precision: 0.6882
# 1_recall: 0.4490
# 1_f1-score: 0.5122
# 1_support: 2657.0000
# 2_precision: 0.3005
# 2_recall: 0.2958
# 2_f1-score: 0.2979
# 2_support: 908.0000
# 3_precision: 0.2723
# 3_recall: 0.1992
# 3_f1-score: 0.2126
# 3_support: 522.0000
# 4_precision: 0.1720
# 4_recall: 0.1679
# 4_f1-score: 0.1699
# 4_support: 293.0000
# 5_precision: 0.2927
# 5_recall: 0.0223
# 5_f1-score: 0.0402
# 5_support: 269.0000
# 6_precision: 0.2000
# 6_recall: 0.1983
# 6_f1-score: 0.1991
# 6_support: 116.0000
# 7_precision: 0.0000
# 7_recall: 0.0000
# 7_f1-score: 0.0000
# 7_support: 53.0000
# 8_precision: 0.0000
# 8_recall: 0.0000
# 8_f1-score: 0.0000
# 8_support: 44.0000
# accuracy: 0.8910
# macro avg_precision: 0.3138
# macro avg_recall: 0.2582
# macro avg_f1-score: 0.2638
# macro avg_support: 31724.0000
# weighted avg_precision: 0.8364
# weighted avg_recall: 0.8910
# weighted avg_f1-score: 0.8550
# weighted avg_support: 31724.0000
