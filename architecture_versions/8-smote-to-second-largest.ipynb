# %%
import warnings
warnings.filterwarnings("ignore")

# %%
import numpy as np
import pandas as pd
import tensorflow as tf

from collections import defaultdict, Counter
from sklearn.utils import resample
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import OneHotEncoder
from sklearn.metrics import classification_report, balanced_accuracy_score, roc_auc_score, average_precision_score, fbeta_score, matthews_corrcoef
from imblearn.over_sampling import SMOTE
from tensorflow.keras.callbacks import EarlyStopping
from tensorflow.keras.models import Model
from tensorflow.keras.layers import Input, Dense, Dropout, Lambda, Concatenate

# %%
def reduce_mem_usage(df):
    """ iterate through all the columns of a dataframe and modify the data type
        to reduce memory usage.        
    """
    start_mem = df.memory_usage().sum() / 1024**2
    print('Memory usage of dataframe is {:.2f} MB'.format(start_mem))
    
    for col in df.columns:
        col_type = df[col].dtype
        
        if col_type != object:
            c_min = df[col].min()
            c_max = df[col].max()
            if str(col_type)[:3] == 'int':
                if c_min > np.iinfo(np.int8).min and c_max < np.iinfo(np.int8).max:
                    df[col] = df[col].astype(np.int8)
                elif c_min > np.iinfo(np.int16).min and c_max < np.iinfo(np.int16).max:
                    df[col] = df[col].astype(np.int16)
                elif c_min > np.iinfo(np.int32).min and c_max < np.iinfo(np.int32).max:
                    df[col] = df[col].astype(np.int32)
                elif c_min > np.iinfo(np.int64).min and c_max < np.iinfo(np.int64).max:
                    df[col] = df[col].astype(np.int64)  
            else:
                if c_min > np.finfo(np.float16).min and c_max < np.finfo(np.float16).max:
                    df[col] = df[col].astype(np.float16)
                elif c_min > np.finfo(np.float32).min and c_max < np.finfo(np.float32).max:
                    df[col] = df[col].astype(np.float32)
                else:
                    df[col] = df[col].astype(np.float64)
        else:
            df[col] = df[col].astype('category')

    end_mem = df.memory_usage().sum() / 1024**2
    print('Memory usage after optimization is: {:.2f} MB'.format(end_mem))
    print('Decreased by {:.1f}%'.format(100 * (start_mem - end_mem) / start_mem))
    
    return df


def import_data(file):
    """create a dataframe and optimize its memory usage"""
    df = pd.read_csv(file, parse_dates=True, keep_date_col=True)
    df = reduce_mem_usage(df)
    return df

# %%
# Custom function to build hidden combination (i.e. convolution) layers

def create_random_combination_layer(input_layer, combination_size, num_combinations, input_dim):
    outputs = []
    
    for _ in range(num_combinations):
        # First random feature selection
        indices_1 = np.random.choice(input_dim, combination_size, replace=False)
        indices_tensor_1 = tf.constant(indices_1, dtype=tf.int32)
        
        # First feature selection using Lambda layer
        slice_layer_1 = Lambda(
            lambda x: tf.gather(x, indices_tensor_1, axis=1),  # Gather selected features
            output_shape=(combination_size,)
        )(input_layer)
        
        # Second random feature selection (after the first random selection)
        indices_2 = np.random.choice(combination_size, combination_size, replace=False)
        indices_tensor_2 = tf.constant(indices_2, dtype=tf.int32)
        
        # Second feature selection using Lambda layer
        slice_layer_2 = Lambda(
            lambda x: tf.gather(x, indices_tensor_2, axis=1),  # Apply a second feature selection
            output_shape=(combination_size,)
        )(slice_layer_1)

        # Apply Dense layers on the final selected subset
        selected_features = Dense(16, activation='relu')(
            Dense(8, activation='relu')(
                Dense(4, activation='relu')(slice_layer_2)
            )
        )
        outputs.append(selected_features)
    
    # Concatenate the outputs from all the random feature combinations
    return Concatenate()(outputs)

# %%
def downsample_largest_class(X, y):
    """
    Downsample the largest class to the size of the second largest class.
    
    Args:
        X (pd.DataFrame or np.array): Features.
        y (pd.Series or np.array): Labels.
        
    Returns:
        tuple: Downsampled X and y.
    """
    # Count class frequencies
    class_counts = Counter(y)
    sorted_classes = sorted(class_counts.items(), key=lambda x: x[1], reverse=True)
    largest_class, largest_count = sorted_classes[0]
    second_largest_count = sorted_classes[1][1]
    
    # Resample the largest class to the size of the second largest
    X_largest = X[y == largest_class]
    y_largest = y[y == largest_class]
    
    X_largest_downsampled, y_largest_downsampled = resample(
        X_largest, y_largest, replace=False, n_samples=second_largest_count, random_state=42
    )
    
    # Combine the downsampled largest class with the rest
    X_rest = X[y != largest_class]
    y_rest = y[y != largest_class]
    X_final = pd.concat([X_rest, X_largest_downsampled])
    y_final = pd.concat([y_rest, y_largest_downsampled])
    
    return X_final, y_final


def apply_smote_after_downsampling(X, y):
    """
    Downsample the largest class to the size of the second largest class,
    then apply SMOTE dynamically based on the smallest class size.
    
    Args:
        X (pd.DataFrame or np.array): Features.
        y (pd.Series or np.array): Labels.
        
    Returns:
        tuple: Resampled X and y.
    """
    # Downsample the largest class
    X, y = downsample_largest_class(X, y)
    
    # Determine n_neighbors dynamically based on the smallest class size
    class_counts = Counter(y)
    min_class_size = min(class_counts.values())
    n_neighbors = min(5, min_class_size - 1)  # Adjust neighbors to fit smallest class
    
    # Apply SMOTE
    smote = SMOTE(random_state=42, k_neighbors=n_neighbors)
    X_resampled, y_resampled = smote.fit_resample(X, y)
    
    return X_resampled, y_resampled

# %%
def run_model(train_data_path, test_data_path, is_string_labels = False, label_mapping = None):

    # Initialize the one-hot encoder for the target
    encoder = OneHotEncoder(sparse_output=False)

    # Load Training Data
    train_data = pd.read_csv(train_data_path)
    train_data = train_data.sample(frac=1).reset_index(drop=True)  # Shuffle

    # Resample Training Data
    X = train_data.iloc[:, :-1]
    y = train_data.iloc[:, -1]
    X_resampled, y_resampled = apply_smote_after_downsampling(X, y)

    # Prepare Training Data
    if (is_string_labels):
        y_resampled = y_resampled.map(label_mapping)
    train_X = X_resampled.to_numpy()
    train_y = y_resampled.to_numpy()
    train_y = encoder.fit_transform(train_y.reshape(-1, 1))

    # Perform a stratified split into train and validation sets (80% train, 20% validation)
    X_train, X_val, y_train, y_val = train_test_split(train_X, train_y, test_size=0.2, random_state=42, stratify=train_y)

    # Load and Prepare Test Data (this will not be used in training)
    test_data = pd.read_csv(test_data_path)
    test_data = test_data.sample(frac=1).reset_index(drop=True)  # Shuffle
    if (is_string_labels):
        test_data['label'] = test_data['label'].map(label_mapping)
    test_X = test_data.drop(columns=['label']).values
    test_y = test_data['label'].values
    test_y = encoder.transform(test_y.reshape(-1, 1))

    # Parameters for Random Feature Combination
    num_combinations = 20  # Number of random column combinations
    combination_size = 3   # Number of columns in each combination

    # EarlyStopping Callback (optional, to avoid overfitting)
    early_stopping = EarlyStopping(monitor='val_loss', patience=10, restore_best_weights=True)

    # Number of runs for averaging results
    num_runs = 5

    # Initialize storage for metrics
    metrics_storage = defaultdict(list)

    # Train the Model with Validation Split N tines for more accurate metrics
    print("Verbose output only for first run...")
    verbose_run = 1
    for run in range(num_runs):
        
        # Model is defined separately in each run, since the random combination layers
        # must be randomly initialized each time. Otherwise, the "random" indices stay the same
        # throughout all runs
        input_layer = Input(shape=(X_train.shape[1],))  # Input shape from the training data
        feature_layer = create_random_combination_layer(input_layer, combination_size, num_combinations, X_train.shape[1])
        hidden_layer = Dense(128, activation='relu')(feature_layer)
        hidden_layer = Dropout(0.5)(hidden_layer)
        output_layer = Dense(test_y.shape[1], activation='softmax')(hidden_layer)
        model = Model(inputs=input_layer, outputs=output_layer)
        model.compile(optimizer='adam', loss='categorical_crossentropy', metrics=['accuracy'])

        print(f"Run {run + 1}/{num_runs} started...")
        history = model.fit(
            X_train, y_train, 
            epochs=1000, 
            batch_size=int(X_train.shape[0] * 0.01), 
            validation_data=(X_val, y_val),
            callbacks=[early_stopping],
            verbose=verbose_run
        )
        verbose_run = 0 # Suppress detailed output for multiple runs

        test_loss, test_acc = model.evaluate(test_X, test_y, verbose=0)
        y_pred = model.predict(test_X, verbose=0)
        y_pred_classes = y_pred.argmax(axis=1)
        y_true_classes = test_y.argmax(axis=1)

        # Compute metrics
        balanced_acc = balanced_accuracy_score(y_true_classes, y_pred_classes)
        roc_auc = roc_auc_score(test_y, y_pred, multi_class='ovr')  # `test_y` is fine here for AUC
        pr_auc = average_precision_score(test_y, y_pred, average='weighted')
        f2 = fbeta_score(y_true_classes, y_pred_classes, beta=2, average='weighted')
        mcc = matthews_corrcoef(y_true_classes, y_pred_classes)

        # Store metrics
        metrics_storage['test_loss'].append(test_loss)
        metrics_storage['test_accuracy'].append(test_acc)
        metrics_storage['balanced_accuracy'].append(balanced_acc)
        metrics_storage['roc_auc'].append(roc_auc)
        metrics_storage['pr_auc'].append(pr_auc)
        metrics_storage['f2'].append(f2)
        metrics_storage['mcc'].append(mcc)

        # Store classification report metrics
        report = classification_report(y_true_classes, y_pred_classes, output_dict=True)
        for label, values in report.items():
            # Check if the value is a dictionary (e.g., 'precision', 'recall', 'f1-score')
            if isinstance(values, dict):
                for metric, value in values.items():
                    metrics_storage[f"{label}_{metric}"].append(value)
            else:
                # Handle scalar values (like 'accuracy')
                metrics_storage[label].append(values)

    # Average the metrics over all runs
    print("\nAggregated Metrics:")
    for metric, values in metrics_storage.items():
        avg_value = np.mean(values)
        print(f"{metric}: {avg_value:.4f}")

# %%
run_model("/kaggle/input/ma-datasets/shuttle_train.csv", "/kaggle/input/ma-datasets/shuttle_test.csv", is_string_labels = False)
# Out:
# Verbose output only for first run...
# Run 1/5 started...
# Epoch 1/1000
# 101/101 ━━━━━━━━━━━━━━━━━━━━ 19s 20ms/step - accuracy: 0.5540 - loss: 1.3248 - val_accuracy: 0.9212 - val_loss: 0.3363
# Epoch 2/1000
# 101/101 ━━━━━━━━━━━━━━━━━━━━ 1s 13ms/step - accuracy: 0.9128 - loss: 0.3222 - val_accuracy: 0.9569 - val_loss: 0.1321
# Epoch 3/1000
# 101/101 ━━━━━━━━━━━━━━━━━━━━ 1s 12ms/step - accuracy: 0.9573 - loss: 0.1657 - val_accuracy: 0.9719 - val_loss: 0.0930
# Epoch 4/1000
# 101/101 ━━━━━━━━━━━━━━━━━━━━ 1s 12ms/step - accuracy: 0.9699 - loss: 0.1169 - val_accuracy: 0.9747 - val_loss: 0.0785
# Epoch 5/1000
# 101/101 ━━━━━━━━━━━━━━━━━━━━ 1s 12ms/step - accuracy: 0.9736 - loss: 0.0954 - val_accuracy: 0.9773 - val_loss: 0.0700
# Epoch 6/1000
# 101/101 ━━━━━━━━━━━━━━━━━━━━ 1s 12ms/step - accuracy: 0.9753 - loss: 0.0834 - val_accuracy: 0.9786 - val_loss: 0.0662
# Epoch 7/1000
# 101/101 ━━━━━━━━━━━━━━━━━━━━ 1s 12ms/step - accuracy: 0.9762 - loss: 0.0802 - val_accuracy: 0.9810 - val_loss: 0.0621
# Epoch 8/1000
# 101/101 ━━━━━━━━━━━━━━━━━━━━ 1s 12ms/step - accuracy: 0.9791 - loss: 0.0730 - val_accuracy: 0.9800 - val_loss: 0.0616
# Epoch 9/1000
# 101/101 ━━━━━━━━━━━━━━━━━━━━ 1s 12ms/step - accuracy: 0.9786 - loss: 0.0702 - val_accuracy: 0.9809 - val_loss: 0.0578
# Epoch 10/1000
# 101/101 ━━━━━━━━━━━━━━━━━━━━ 1s 13ms/step - accuracy: 0.9795 - loss: 0.0673 - val_accuracy: 0.9812 - val_loss: 0.0565
# Epoch 11/1000
# 101/101 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - accuracy: 0.9800 - loss: 0.0628 - val_accuracy: 0.9817 - val_loss: 0.0564
# Epoch 12/1000
# 101/101 ━━━━━━━━━━━━━━━━━━━━ 1s 12ms/step - accuracy: 0.9800 - loss: 0.0690 - val_accuracy: 0.9824 - val_loss: 0.0562
# Epoch 13/1000
# 101/101 ━━━━━━━━━━━━━━━━━━━━ 1s 14ms/step - accuracy: 0.9810 - loss: 0.0593 - val_accuracy: 0.9807 - val_loss: 0.0562
# Epoch 14/1000
# 101/101 ━━━━━━━━━━━━━━━━━━━━ 1s 13ms/step - accuracy: 0.9826 - loss: 0.0601 - val_accuracy: 0.9851 - val_loss: 0.0513
# Epoch 15/1000
# 101/101 ━━━━━━━━━━━━━━━━━━━━ 1s 12ms/step - accuracy: 0.9838 - loss: 0.0546 - val_accuracy: 0.9813 - val_loss: 0.0539
# Epoch 16/1000
# 101/101 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - accuracy: 0.9831 - loss: 0.0546 - val_accuracy: 0.9855 - val_loss: 0.0496
# Epoch 17/1000
# 101/101 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - accuracy: 0.9835 - loss: 0.0544 - val_accuracy: 0.9857 - val_loss: 0.0483
# Epoch 18/1000
# 101/101 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - accuracy: 0.9841 - loss: 0.0564 - val_accuracy: 0.9830 - val_loss: 0.0490
# Epoch 19/1000
# 101/101 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - accuracy: 0.9850 - loss: 0.0497 - val_accuracy: 0.9855 - val_loss: 0.0461
# Epoch 20/1000
# 101/101 ━━━━━━━━━━━━━━━━━━━━ 1s 12ms/step - accuracy: 0.9850 - loss: 0.0499 - val_accuracy: 0.9867 - val_loss: 0.0477
# Epoch 21/1000
# 101/101 ━━━━━━━━━━━━━━━━━━━━ 1s 12ms/step - accuracy: 0.9847 - loss: 0.0502 - val_accuracy: 0.9866 - val_loss: 0.0449
# Epoch 22/1000
# 101/101 ━━━━━━━━━━━━━━━━━━━━ 1s 12ms/step - accuracy: 0.
1000
# 101/101 ━━━━━━━━━━━━━━━━━━━━ 1s 12ms/step - accuracy: 0.9891 - loss: 0.0366 - val_accuracy: 0.9888 - val_loss: 0.0382
# Epoch 55/1000
# 101/101 ━━━━━━━━━━━━━━━━━━━━ 1s 12ms/step - accuracy: 0.9899 - loss: 0.0397 - val_accuracy: 0.9887 - val_loss: 0.0389
# Epoch 56/1000
# 101/101 ━━━━━━━━━━━━━━━━━━━━ 1s 13ms/step - accuracy: 0.9900 - loss: 0.0323 - val_accuracy: 0.9880 - val_loss: 0.0399
# Run 2/5 started...
# Run 3/5 started...
# Run 4/5 started...
# Run 5/5 started...
#
# Aggregated Metrics:
# test_loss: 0.5088
# test_accuracy: 0.8465
# balanced_accuracy: 0.8396
# roc_auc: 0.9530
# pr_auc: 0.9517
# f2: 0.8607
# mcc: 0.7208
# 0_precision: 0.9852
# 0_recall: 0.8472
# 0_f1-score: 0.9045
# 0_support: 9117.0000
# 1_precision: 0.4468
# 1_recall: 0.8400
# 1_f1-score: 0.5017
# 1_support: 10.0000
# 2_precision: 0.3624
# 2_recall: 0.7529
# 2_f1-score: 0.4242
# 2_support: 34.0000
# 3_precision: 0.7892
# 3_recall: 0.7989
# 3_f1-score: 0.7888
# 3_support: 1781.0000
# 4_precision: 0.9552
# 4_recall: 0.9715
# 4_f1-score: 0.9630
# 4_support: 653.0000
# 5_precision: 0.3838
# 5_recall: 0.8000
# 5_f1-score: 0.4551
# 5_support: 2.0000
# 6_precision: 0.2613
# 6_recall: 0.8667
# 6_f1-score: 0.3636
# 6_support: 3.0000
# accuracy: 0.8465
# macro avg_precision: 0.5977
# macro avg_recall: 0.8396
# macro avg_f1-score: 0.6287
# macro avg_support: 11600.0000
# weighted avg_precision: 0.9509
# weighted avg_recall: 0.8465
# weighted avg_f1-score: 0.8880
# weighted avg_support: 11600.0000

# %%
run_model("/kaggle/input/ma-datasets/covtype_train.csv", "/kaggle/input/ma-datasets/covtype_test.csv", is_string_labels = False)
# Out:
# Verbose output only for first run...
# Run 1/5 started...
# Epoch 1/1000
# 101/101 ━━━━━━━━━━━━━━━━━━━━ 25s 81ms/step - accuracy: 0.1780 - loss: 1.9235 - val_accuracy: 0.1902 - val_loss: 1.9075
# Epoch 2/1000
# 101/101 ━━━━━━━━━━━━━━━━━━━━ 7s 68ms/step - accuracy: 0.1880 - loss: 1.9120 - val_accuracy: 0.1943 - val_loss: 1.9054
# Epoch 3/1000
# 101/101 ━━━━━━━━━━━━━━━━━━━━ 7s 66ms/step - accuracy: 0.1901 - loss: 1.9102 - val_accuracy: 0.1966 - val_loss: 1.9045
# Epoch 4/1000
# 101/101 ━━━━━━━━━━━━━━━━━━━━ 7s 69ms/step - accuracy: 0.1921 - loss: 1.9082 - val_accuracy: 0.1944 - val_loss: 1.9039
# Epoch 5/1000
# 101/101 ━━━━━━━━━━━━━━━━━━━━ 7s 67ms/step - accuracy: 0.1925 - loss: 1.9087 - val_accuracy: 0.1954 - val_loss: 1.9035
# Epoch 6/1000
# 101/101 ━━━━━━━━━━━━━━━━━━━━ 8s 75ms/step - accuracy: 0.1921 - loss: 1.9082 - val_accuracy: 0.1942 - val_loss: 1.9027
# Epoch 7/1000
# 101/101 ━━━━━━━━━━━━━━━━━━━━ 7s 67ms/step - accuracy: 0.1931 - loss: 1.9070 - val_accuracy: 0.1972 - val_loss: 1.9024
# Epoch 8/1000
# 101/101 ━━━━━━━━━━━━━━━━━━━━ 7s 69ms/step - accuracy: 0.1933 - loss: 1.9063 - val_accuracy: 0.1975 - val_loss: 1.9018
# Epoch 9/1000
# 101/101 ━━━━━━━━━━━━━━━━━━━━ 7s 68ms/step - accuracy: 0.1930 - loss: 1.9062 - val_accuracy: 0.1944 - val_loss: 1.9014
# Epoch 10/1000
# 101/101 ━━━━━━━━━━━━━━━━━━━━ 7s 72ms/step - accuracy: 0.1930 - loss: 1.9059 - val_accuracy: 0.1969 - val_loss: 1.9014
# Epoch 11/1000
# 101/101 ━━━━━━━━━━━━━━━━━━━━ 7s 67ms/step - accuracy: 0.1928 - loss: 1.9064 - val_accuracy: 0.1958 - val_loss: 1.9017
# Epoch 12/1000
# 101/101 ━━━━━━━━━━━━━━━━━━━━ 10s 67ms/step - accuracy: 0.1934 - loss: 1.9054 - val_accuracy: 0.1962 - val_loss: 1.9008
# Epoch 13/1000
# 101/101 ━━━━━━━━━━━━━━━━━━━━ 7s 67ms/step - accuracy: 0
1000
# 101/101 ━━━━━━━━━━━━━━━━━━━━ 7s 66ms/step - accuracy: 0.2152 - loss: 1.8669 - val_accuracy: 0.2263 - val_loss: 1.8360
# Epoch 166/1000
# 101/101 ━━━━━━━━━━━━━━━━━━━━ 7s 66ms/step - accuracy: 0.2216 - loss: 1.8458 - val_accuracy: 0.2067 - val_loss: 1.8700
# Epoch 167/1000
# 101/101 ━━━━━━━━━━━━━━━━━━━━ 7s 72ms/step - accuracy: 0.2186 - loss: 1.8530 - val_accuracy: 0.2235 - val_loss: 1.8353
# Epoch 168/1000
# 101/101 ━━━━━━━━━━━━━━━━━━━━ 7s 69ms/step - accuracy: 0.2197 - loss: 1.8514 - val_accuracy: 0.2204 - val_loss: 1.8466
# Epoch 169/1000
# 101/101 ━━━━━━━━━━━━━━━━━━━━ 7s 67ms/step - accuracy: 0.2215 - loss: 1.8462 - val_accuracy: 0.2292 - val_loss: 1.8449
# Run 2/5 started...
# Run 3/5 started...
# Run 4/5 started...
# Run 5/5 started...
#
# Aggregated Metrics:
# test_loss: 1.8412
# test_accuracy: 0.2438
# balanced_accuracy: 0.2216
# roc_auc: 0.5914
# pr_auc: 0.4106
# f2: 0.2257
# mcc: 0.0631
# 0_precision: 0.4444
# 0_recall: 0.1938
# 0_f1-score: 0.2023
# 0_support: 42368.0000
# 1_precision: 0.4444
# 1_recall: 0.2976
# 1_f1-score: 0.2813
# 1_support: 56661.0000
# 2_precision: 0.2043
# 2_recall: 0.1598
# 2_f1-score: 0.1361
# 2_support: 7151.0000
# 3_precision: 0.0062
# 3_recall: 0.2510
# 3_f1-score: 0.0114
# 3_support: 549.0000
# 4_precision: 0.0130
# 4_recall: 0.2354
# 4_f1-score: 0.0240
# 4_support: 1899.0000
# 5_precision: 0.0363
# 5_recall: 0.2637
# 5_f1-score: 0.0624
# 5_support: 3473.0000
# 6_precision: 0.1907
# 6_recall: 0.1501
# 6_f1-score: 0.1490
# 6_support: 4102.0000
# accuracy: 0.2438
# macro avg_precision: 0.1913
# macro avg_recall: 0.2216
# macro avg_f1-score: 0.1238
# macro avg_support: 116203.0000
# weighted avg_precision: 0.3993
# weighted avg_recall: 0.2438
# weighted avg_f1-score: 0.2269
# weighted avg_support: 116203.0000

# %%
labels_map = {
    'normal.': 0, 'satan.': 1, 'ipsweep.': 2, 'portsweep.': 3, 'nmap.': 4,
    'back.': 5, 'warezclient.': 6, 'teardrop.': 7, 'pod.': 8, 'guess_passwd.': 9,
    'buffer_overflow.': 10, 'land.': 11, 'warezmaster.': 12, 'imap.': 13, 'rootkit.': 14,
    'loadmodule.': 15, 'multihop.': 16, 'ftp_write.': 17, 'phf.': 18, 'perl.': 19, 'spy.': 20
}

run_model("/kaggle/input/ma-datasets/kdd_train.csv", "/kaggle/input/ma-datasets/kdd_test.csv", is_string_labels = True, label_mapping = labels_map)
# Out:
# Verbose output only for first run...
# Run 1/5 started...
# Epoch 1/1000
# 101/101 ━━━━━━━━━━━━━━━━━━━━ 21s 31ms/step - accuracy: 0.1160 - loss: 2.9315 - val_accuracy: 0.1956 - val_loss: 2.5011
# Epoch 2/1000
# 101/101 ━━━━━━━━━━━━━━━━━━━━ 2s 23ms/step - accuracy: 0.2058 - loss: 2.4977 - val_accuracy: 0.2791 - val_loss: 2.3376
# Epoch 3/1000
# 101/101 ━━━━━━━━━━━━━━━━━━━━ 2s 22ms/step - accuracy: 0.2533 - loss: 2.3466 - val_accuracy: 0.2885 - val_loss: 2.2464
# Epoch 4/1000
# 101/101 ━━━━━━━━━━━━━━━━━━━━ 2s 23ms/step - accuracy: 0.2766 - loss: 2.2608 - val_accuracy: 0.3072 - val_loss: 2.1758
# Epoch 5/1000
# 101/101 ━━━━━━━━━━━━━━━━━━━━ 2s 23ms/step - accuracy: 0.2917 - loss: 2.1891 - val_accuracy: 0.3120 - val_loss: 2.1098
# Epoch 6/1000
# 101/101 ━━━━━━━━━━━━━━━━━━━━ 3s 26ms/step - accuracy: 0.2975 - loss: 2.1403 - val_accuracy: 0.3167 - val_loss: 2.0657
# Epoch 7/1000
# 101/101 ━━━━━━━━━━━━━━━━━━━━ 3s 27ms/step - accuracy: 0.3023 - loss: 2.0968 - val_accuracy: 0.3190 - val_loss: 2.0378
# Epoch 8/1000
# 101/101 ━━━━━━━━━━━━━━━━━━━━ 2s 23ms/step - accuracy: 0.3016 - loss: 2.0718 - val_accuracy: 0.3145 - val_loss: 2.0238
# Epoch 9/1000
# 101/101 ━━━━━━━━━━━━━━━━━━━━ 2s 23ms/step - accuracy: 0.3040 - loss: 2.0535 - val_accuracy: 0.3168 - val_loss: 2.0040
# Epoch 10/1000
# 101/101 ━━━━━━━━━━━━━━━━━━━━ 2s 23ms/step - accuracy: 0.3089 - loss: 2.0332 - val_accuracy: 0.3206 - val_loss: 1.9867
# Epoch 11/1000
# 101/101 ━━━━━━━━━━━━━━━━━━━━ 2s 24ms/step - accuracy: 0.3081 - loss: 2.0275 - val_accuracy: 0.3235 - val_loss: 1.9786
# Epoch 12/1000
# 101/101 ━━━━━━━━━━━━━━━━━━━━ 2s 23ms/step - accuracy: 0.3110 - loss: 2.0182 - val_accuracy: 0.3228 - val_loss: 1.9822
# Epoch 13/1000
# 101/101 ━━━━━━━━━━━━━━━━━━━━ 2s 23ms/step - accuracy: 0.3133 - loss: 2.0051 - val_accuracy: 0.3233 - val_loss: 1.9718
# Epoch 14/1000
# 101/101 ━━━━━━━━━━━━━━━━━━━━ 2s 23ms/step - accuracy: 0.3149 - loss: 1.9998 - val_accuracy: 0.3143 - val_loss: 1.9766
# Epoch 15/1000
# 101/101 ━━━━━━━━━━━━━━━━━━━━ 2s 22ms/step - accuracy: 0.3174 - loss: 1.9967 - val_accuracy: 0.3056 - val_loss: 1.9954
# Epoch 16/1000
# 101/101 ━━━━━━━━━━━━━━━━━━━━ 2s 23ms/step - accuracy: 0.3169 - loss: 1.9989 - val_accuracy: 0.3364 - val_loss: 1.9541
# Epoch 17/1000
# 101/101 ━━━━━━━━━━━━━━━━━━━━ 2s 23ms/step - accuracy: 0.3202 - loss: 1.9860 - val_accuracy: 0.3359 - val_loss: 1.9493
# Epoch 18/1000
# 101/101 ━━━━━━━━━━━━━━━━━━━━ 2s 23ms/step - accuracy: 0.3191 - loss: 1.9880 - val_accuracy: 0.3355 - val_loss: 1.9451
# Epoch 19/1000
# 101/101 ━━━━━━━━━━━━━━━━━━━━ 3s 26ms/step - accuracy: 0.3197 - loss: 1.9843 - val_accuracy: 0.3301 - val_loss: 1.9424
# Epoch 20/1000
# 101/101 ━━━━━━━━━━━━━━━━━━━━ 2s 24ms/step - accuracy: 0.3232 - loss: 1.9703 - val_accuracy: 0.3318 - val_loss: 1.9407
# Epoch 21/1000
# 101/101 ━━━━━━━━━━━━━━━━━━━━ 3s 26ms/step - accuracy: 0.3236 - loss: 1.9755 - val_accuracy: 0.3322 - val_loss: 1.9450
# Epoch 22/1000
# 101/101 ━━━━━━━━━━━━━━━━━━━━ 2s 23ms/step - accuracy: 0.3237 - loss: 1.9715 - val_accuracy: 0.3404 - val_loss: 1.9424
# Epoch 23/1000
# 101/101 ━━━━━━━━━━━━━━━━━━━━ 2s 22ms/step - accuracy: 0.3245 - loss: 1.9735 - val_accuracy: 0.3070 - val_loss: 1.9583
# Epoch 24/1000
# 101/101 ━━━━━━━━━━━━━━━━━━━━ 2s 23ms/step - accuracy: 0.3226 - loss: 1.9724 - val_accuracy: 0.3388 - val_loss: 1.9342
# Epoch 25/1000
# 101/101 ━━━━━━━━━━━━━━━━━━━━ 2s 22ms/step - accuracy: 0.3264 - loss: 1.9633 - val_accuracy: 0.3324 - val_loss: 1.9395
# Epoch 26/1000
# 101/101 ━━━━━━━━━━━━━━━━━━━━ 2s 23ms/step - accuracy: 0.3291 - loss: 1.9593 - val_accuracy: 0.3255 - val_loss: 1.9483
# Epoch 27/1000
# 101/101 ━━━━━━━━━━━━━━━━━━━━ 2s 23ms/step - accuracy: 0.3262 - loss: 1.9556 - val_accuracy: 0.3413 - val_loss: 1.9292
# Epoch 28/1000
# 101/101 ━━━━━━━━━━━━━━━━━━━━ 2s 23ms/step - accuracy: 0.3280 - loss: 1.9529 - val_accuracy: 0.3346 - val_loss: 1.9321
# Epoch 29/1000
# 101/101 ━━━━━━━━━━━━━━━━━━━━ 2s 22ms/step - accuracy: 0.3285 - loss: 1.9528 - val_accuracy: 0.3267 - val_loss: 1.9390
# Epoch 30/1000
# 101/101 ━━━━━━━━━━━━━━━━━━━━ 2s 22ms/step - accuracy: 0.3300 - loss: 1.9533 - val_accuracy: 0.3252 - val_loss: 1.9428
# Epoch 31/1000
# 101/101 ━━━━━━━━━━━━━━━━━━━━ 2s 23ms/step - accuracy: 0.3249 - loss: 1.9614 - val_accuracy: 0.3332 - val_loss: 1.9351
# Epoch 32/1000
# 101/101 ━━━━━━━━━━━━━━━━━━━━ 3s 25ms/step - accuracy: 0.3303 - loss: 1.9466 - val_accuracy: 0.3219 - val_loss: 1.9521
# Epoch 33/1000
# 101/101 ━━━━━━━━━━━━━━━━━━━━ 3s 25ms/step - accuracy: 0.3264 - loss: 1.9562 - val_accuracy: 0.3418 - val_loss: 1.9210
# Epoch 34/1000
# 101/101 ━━━━━━━━━━━━━━━━━━━━ 3s 26ms/step - accuracy: 0.3298 - loss: 1.9513 - val_accuracy: 0.3359 - val_loss: 1.9252
# Epoch 35/1000
# 101/101 ━━━━━━━━━━━━━━━━━━━━ 2s 23ms/step - accuracy: 0.3311 - loss: 1.9468 - val_accuracy: 0.3390 - val_loss: 1.9190
# Epoch 36/1000
# 101/101 ━━━━━━━━━━━━━━━━━━━━ 2s 22ms/step - accuracy: 0.3318 - loss: 1.9473 - val_accuracy: 0.3425 - val_loss: 1.9163
# Epoch 37/1000
# 101/101 ━━━━━━━━━━━━━━━━━━━━ 3s 22ms/step - accuracy: 0.3325 - loss: 1.9438 - val_accuracy: 0.3349 - val_loss: 1.9284
# Epoch 38/1000
# 101/101 ━━━━━━━━━━━━━━━━━━━━ 2s 22ms/step - accuracy: 0.3351 - loss: 1.9372 - val_accuracy: 0.3303 - val_loss: 1.9304
# Epoch 39/1000
# 101/101 ━━━━━━━━━━━━━━━━━━━━ 2s 23ms/step - accuracy: 0.3307 - loss: 1.9484 - val_accuracy: 0.3318 - val_loss: 1.9293
# Epoch 40/1000
# 101/101 ━━━━━━━━━━━━━━━━━━━━ 2s 22ms/step - accuracy: 0.3353 - loss: 1.9430 - val_accuracy: 0.3471 - val_loss: 1.9113
# Epoch 41/1000
# 101/101 ━━━━━━━━━━━━━━━━━━━━ 2s 22ms/step - accuracy: 0.3378 - loss: 1.9318 - val_accuracy: 0.3259 - val_loss: 1.9403
# Epoch 42/1000
# 101/101 ━━━━━━━━━━━━━━━━━━━━ 2s 22ms/step - accuracy: 0.3256 - loss: 1.9702 - val_accuracy: 0.3356 - val_loss: 1.9182
# Epoch 43/1000
# 101/101 ━━━━━━━━━━━━━━━━━━━━ 2s 23ms/step - accuracy: 0.3378 - loss: 1.9405 - val_accuracy: 0.3477 - val_loss: 1.9082
# Epoch 44/1000
# 101/101 ━━━━━━━━━━━━━━━━━━━━ 2s 22ms/step - accuracy: 0.3354 - loss: 1.9405 - val_accuracy: 0.3384 - val_loss: 1.9196
# Epoch 45/1000
# 101/101 ━━━━━━━━━━━━━━━━━━━━ 3s 22ms/step - accuracy: 0.3352 - loss: 1.9404 - val_accuracy: 0.3418 - val_loss: 1.9143
# Epoch 46/1000
# 101/101 ━━━━━━━━━━━━━━━━━━━━ 3s 27ms/step - accuracy: 0.3318 - loss: 1.9425 - val_accuracy: 0.3428 - val_loss: 1.9048
# Epoch 47/1000
# 101/101 ━━━━━━━━━━━━━━━━━━━━ 2s 23ms/step - accuracy: 0.3364 - loss: 1.9390 - val_accuracy: 0.3467 - val_loss: 1.9313
# Epoch 48/1000
# 101/101 ━━━━━━━━━━━━━━━━━━━━ 3s 26ms/step - accuracy: 0.3352 - loss: 1.9411 - val_accuracy: 0.3477 - val_loss: 1.9023
# Epoch 49/1000
# 101/101 ━━━━━━━━━━━━━━━━━━━━ 2s 23ms/step - accuracy: 0.3418 - loss: 1.9301 - val_accuracy: 0.3495 - val_loss: 1.8989
# Epoch 50/1000
# 101/101 ━━━━━━━━━━━━━━━━━━━━ 2s 23ms/step - accuracy: 0.3425 - loss: 1.9257 - val_accuracy: 0.3416 - val_loss: 1.9214
# Epoch 51/1000
# 101/101 ━━━━━━━━━━━━━━━━━━━━ 2s 23ms/step - accuracy: 0.3416 - loss: 1.9280 - val_accuracy: 0.3432 - val_loss: 1.9102
# Epoch 52/1000
# 101/101 ━━━━━━━━━━━━━━━━━━━━ 2s 22ms/step - accuracy: 0.3378 - loss: 1.9346 - val_accuracy: 0.3510 - val_loss: 1.9049
# Epoch 53/1000
# 101/101 ━━━━━━━━━━━━━━━━━━━━ 2s 22ms/step - accuracy: 0.3418 - loss: 1.9315 - val_accuracy: 0.3429 - val_loss: 1.9081
# Epoch 54/1000
# 101/101 ━━━━━━━━━━━━━━━━━━━━ 2s 22ms/step - accuracy: 0.3454 - loss: 1.9216 - val_accuracy: 0.3311 - val_loss: 1.9108
# Epoch 55/1000
# 101/101 ━━━━━━━━━━━━━━━━━━━━ 2s 22ms/step - accuracy: 0.3414 - loss: 1.9257 - val_accuracy: 0.3469 - val_loss: 1.9092
# Epoch 56/1000
# 101/101 ━━━━━━━━━━━━━━━━━━━━ 2s 23ms/step - accuracy: 0.3362 - loss: 1.9455 - val_accuracy: 0.3671 - val_loss: 1.8935
# Epoch 57/1000
# 101/101 ━━━━━━━━━━━━━━━━━━━━ 2s 22ms/step - accuracy: 0.3455 - loss: 1.9258 - val_accuracy: 0.3550 - val_loss: 1.9045
# Epoch 58/1000
# 101/101 ━━━━━━━━━━━━━━━━━━━━ 2s 22ms/step - accuracy: 0.3454 - loss: 1.9244 - val_accuracy: 0.3330 - val_loss: 1.9185
# Epoch 59/1000
# 101/101 ━━━━━━━━━━━━━━━━━━━━ 2s 24ms/step - accuracy: 0.3415 - loss: 1.9288 - val_accuracy: 0.3486 - val_loss: 1.8926
# Epoch 60/1000
# 101/101 ━━━━━━━━━━━━━━━━━━━━ 3s 26ms/step - accuracy: 0.3453 - loss: 1.9199 - val_accuracy: 0.3510 - val_loss: 1.9101
# Epoch 61/1000
# 101/101 ━━━━━━━━━━━━━━━━━━━━ 3s 25ms/step - accuracy: 0.3480 - loss: 1.9207 - val_accuracy: 0.3466 - val_loss: 1.8995
# Epoch 62/1000
# 101/101 ━━━━━━━━━━━━━━━━━━━━ 2s 24ms/step - accuracy: 0.3470 - loss: 1.9229 - val_accuracy: 0.3733 - val_loss: 1.8878
# Epoch 63/1000
# 101/101 ━━━━━━━━━━━━━━━━━━━━ 2s 24ms/step - accuracy: 0.3527 - loss: 1.9111 - val_accuracy: 0.3440 - val_loss: 1.8953
# Epoch 64/1000
# 101/101 ━━━━━━━━━━━━━━━━━━━━ 2s 24ms/step - accuracy: 0.3504 - loss: 1.9138 - val_accuracy: 0.3443 - val_loss: 1.9001
# Epoch 65/1000
# 101/101 ━━━━━━━━━━━━━━━━━━━━ 2s 23ms/step - accuracy: 0.3489 - loss: 1.9166 - val_accuracy: 0.3533 - val_loss: 1.9422
# Epoch 66/1000
# 101/101 ━━━━━━━━━━━━━━━━━━━━ 2s 23ms/step - accuracy: 0.3414 - loss: 1.9342 - val_accuracy: 0.3676 - val_loss: 1.8927
# Epoch 67/1000
# 101/101 ━━━━━━━━━━━━━━━━━━━━ 2s 24ms/step - accuracy: 0.3528 - loss: 1.9099 - val_accuracy: 0.3769 - val_loss: 1.8863
# Epoch 68/1000
# 101/101 ━━━━━━━━━━━━━━━━━━━━ 2s 24ms/step - accuracy: 0.3492 - loss: 1.9143 - val_accuracy: 0.3363 - val_loss: 1.8983
# Epoch 69/1000
# 101/101 ━━━━━━━━━━━━━━━━━━━━ 2s 24ms/step - accuracy: 0.3489 - loss: 1.9154 - val_accuracy: 0.3715 - val_loss: 1.8782
# Epoch 70/1000
# 101/101 ━━━━━━━━━━━━━━━━━━━━ 2s 24ms/step - accuracy: 0.3490 - loss: 1.9116 - val_accuracy: 0.3737 - val_loss: 1.8881
# Epoch 71/1000
# 101/101 ━━━━━━━━━━━━━━━━━━━━ 2s 22ms/step - accuracy: 0.3515 - loss: 1.9116 - val_accuracy: 0.3736 - val_loss: 1.8931
# Epoch 72/1000
# 101/101 ━━━━━━━━━━━━━━━━━━━━ 2s 23ms/step - accuracy: 0.3485 - loss: 1.9170 - val_accuracy: 0.3481 - val_loss: 1.8925
# Epoch 73/1000
# 101/101 ━━━━━━━━━━━━━━━━━━━━ 3s 26ms/step - accuracy: 0.3521 - loss: 1.9077 - val_accuracy: 0.3516 - val_loss: 1.8787
# Epoch 74/1000
# 101/101 ━━━━━━━━━━━━━━━━━━━━ 2s 24ms/step - accuracy: 0.3521 - loss: 1.9101 - val_accuracy: 0.3550 - val_loss: 1.8902
# Epoch 75/1000
# 101/101 ━━━━━━━━━━━━━━━━━━━━ 3s 25ms/step - accuracy: 0.3511 - loss: 1.9068 - val_accuracy: 0.3536 - val_loss: 1.9058
# Epoch 76/1000
# 101/101 ━━━━━━━━━━━━━━━━━━━━ 2s 23ms/step - accuracy: 0.3516 - loss: 1.9153 - val_accuracy: 0.3647 - val_loss: 1.8865
# Epoch 77/1000
# 101/101 ━━━━━━━━━━━━━━━━━━━━ 2s 22ms/step - accuracy: 0.3551 - loss: 1.9062 - val_accuracy: 0.3454 - val_loss: 1.8994
# Epoch 78/1000
# 101/101 ━━━━━━━━━━━━━━━━━━━━ 2s 22ms/step - accuracy: 0.3502 - loss: 1.9180 - val_accuracy: 0.3641 - val_loss: 1.8792
# Epoch 79/1000
# 101/101 ━━━━━━━━━━━━━━━━━━━━ 2s 22ms/step - accuracy: 0.3528 - loss: 1.9133 - val_accuracy: 0.3785 - val_loss: 1.8797
# Run 2/5 started...
# Run 3/5 started...
# Run 4/5 started...
# Run 5/5 started...
#
# Aggregated Metrics:
# test_loss: 2.9194
# test_accuracy: 0.0131
# balanced_accuracy: 0.0853
# roc_auc: 0.5724
# pr_auc: 0.9210
# f2: 0.0096
# mcc: 0.0175
# 0_precision: 0.3998
# 0_recall: 0.0062
# 0_f1-score: 0.0120
# 0_support: 194557.0000
# 1_precision: 0.0433
# 1_recall: 0.3765
# 1_f1-score: 0.0716
# 1_support: 3178.0000
# 2_precision: 0.0545
# 2_recall: 0.0002
# 2_f1-score: 0.0005
# 2_support: 2496.0000
# 3_precision: 0.0428
# 3_recall: 0.0385
# 3_f1-score: 0.0372
# 3_support: 2083.0000
# 4_precision: 0.0000
# 4_recall: 0.0000
# 4_f1-score: 0.0000
# 4_support: 463.0000
# 5_precision: 0.0012
# 5_recall: 0.3959
# 5_f1-score: 0.0024
# 5_support: 441.0000
# 6_precision: 0.0011
# 6_recall: 0.0569
# 6_f1-score: 0.0022
# 6_support: 204.0000
# 7_precision: 0.0000
# 7_recall: 0.0000
# 7_f1-score: 0.0000
# 7_support: 196.0000
# 8_precision: 0.0000
# 8_recall: 0.0000
# 8_f1-score: 0.0000
# 8_support: 53.0000
# 9_precision: 0.0000
# 9_recall: 0.0000
# 9_f1-score: 0.0000
# 9_support: 11.0000
# 10_precision: 0.0008
# 10_recall: 0.0667
# 10_f1-score: 0.0015
# 10_support: 6.0000
# 11_precision: 0.0000
# 11_recall: 0.0000
# 11_f1-score: 0.0000
# 11_support: 4.0000
# 12_precision: 0.0001
# 12_recall: 0.0500
# 12_f1-score: 0.0003
# 12_support: 4.0000
# 13_precision: 0.0000
# 13_recall: 0.2000
# 13_f1-score: 0.0000
# 13_support: 2.0000
# 14_precision: 0.0000
# 14_recall: 0.2000
# 14_f1-score: 0.0000
# 14_support: 2.0000
# 15_precision: 0.0000
# 15_recall: 0.0000
# 15_f1-score: 0.0000
# 15_support: 2.0000
# 16_precision: 0.0000
# 16_recall: 0.0000
# 16_f1-score: 0.0000
# 16_support: 1.0000
# 17_precision: 0.0000
# 17_recall: 0.0000
# 17_f1-score: 0.0000
# 17_support: 2.0000
# 18_precision: 0.0000
# 18_recall: 0.0000
# 18_f1-score: 0.0000
# 18_support: 1.0000
# 19_precision: 0.0004
# 19_recall: 0.2000
# 19_f1-score: 0.0008
# 19_support: 1.0000
# 20_precision: 0.0023
# 20_recall: 0.2000
# 20_f1-score: 0.0045
# 20_support: 1.0000
# accuracy: 0.0131
# macro avg_precision: 0.0260
# macro avg_recall: 0.0853
# macro avg_f1-score: 0.0063
# macro avg_support: 203708.0000
# weighted avg_precision: 0.3836
# weighted avg_recall: 0.0131
# weighted avg_f1-score: 0.0129
# weighted avg_support: 203708.0000

# %%
labels_map = {
    'Normal': 0, 'Darknet_Audio-Streaming': 1, 'Darknet_Chat': 2, 'Darknet_File-Transfer': 3, 'Darknet_VOIP': 4,
    'Darknet_Video-Streaming': 5, 'Darknet_Email': 6, 'Darknet_Browsing': 7, 'Darknet_P2P': 8
}

run_model("/kaggle/input/ma-datasets/darknet_train.csv", "/kaggle/input/ma-datasets/darknet_test.csv", is_string_labels = True, label_mapping = labels_map)
# Out:
# Verbose output only for first run...
# Run 1/5 started...
# Epoch 1/1000
# 101/101 ━━━━━━━━━━━━━━━━━━━━ 21s 21ms/step - accuracy: 0.2210 - loss: 2.0153 - val_accuracy: 0.2893 - val_loss: 1.8739
# Epoch 2/1000
# 101/101 ━━━━━━━━━━━━━━━━━━━━ 1s 14ms/step - accuracy: 0.2823 - loss: 1.8915 - val_accuracy: 0.3048 - val_loss: 1.8373
# Epoch 3/1000
# 101/101 ━━━━━━━━━━━━━━━━━━━━ 2s 15ms/step - accuracy: 0.3044 - loss: 1.8601 - val_accuracy: 0.3195 - val_loss: 1.8142
# Epoch 4/1000
# 101/101 ━━━━━━━━━━━━━━━━━━━━ 1s 13ms/step - accuracy: 0.3083 - loss: 1.8377 - val_accuracy: 0.3127 - val_loss: 1.8009
# Epoch 5/1000
# 101/101 ━━━━━━━━━━━━━━━━━━━━ 1s 13ms/step - accuracy: 0.3207 - loss: 1.8228 - val_accuracy: 0.3128 - val_loss: 1.8002
# Epoch 6/1000
# 101/101 ━━━━━━━━━━━━━━━━━━━━ 1s 14ms/step - accuracy: 0.3148 - loss: 1.8200 - val_accuracy: 0.3249 - val_loss: 1.7854
# Epoch 7/1000
# 101/101 ━━━━━━━━━━━━━━━━━━━━ 1s 13ms/step - accuracy: 0.3242 - loss: 1.8080 - val_accuracy: 0.3283 - val_loss: 1.7797
# Epoch 8/1000
# 101/101 ━━━━━━━━━━━━━━━━━━━━ 1s 14ms/step - accuracy: 0.3210 - loss: 1.8021 - val_accuracy: 0.3280 - val_loss: 1.7768
# Epoch 9/1000
# 101/101 ━━━━━━━━━━━━━━━━━━━━ 1s 14ms/step - accuracy: 0.3268 - loss: 1.7909 - val_accuracy: 0.3300 - val_loss: 1.7767
# Epoch 10/1000
# 101/101 ━━━━━━━━━━━━━━━━━━━━ 1s 14ms/step - accuracy: 0.3261 - loss: 1.7973 - val_accuracy: 0.3307 - val_loss: 1.7758
# Epoch 11/1000
# 101/101 ━━━━━━━━━━━━━━━━━━━━ 1s 14ms/step - accuracy: 0.3262 - loss: 1.7944 - val_accuracy: 0.3296 - val_loss: 1.7739
# Epoch 12/1000
# 101/101 ━━━━━━━━━━━━━━━━━━━━ 1s 14ms/step - accuracy: 0.3280 - loss: 1.7898 - val_accuracy: 0.3282 - val_loss: 1.7673
# Epoch 13/1000
# 101/101 ━━━━━━━━━━━━━━━━━━━━ 1s 14ms/step - accuracy: 0.3281 - loss: 1.7888 - val_accuracy: 0.3251 - val_loss: 1.7681
# Epoch 14/1000
# 101/101 ━━━━━━━━━━━━━━━━━━━━ 1s 14ms/step - accuracy: 0.3305 - loss: 1.7860 - val_accuracy: 0.3338 - val_loss: 1.7700
# Epoch 15/1000
# 101/101 ━━━━━━━━━━━━━━━━━━━━ 1s 14ms/step - accuracy: 0.3254 - loss: 1.7885 - val_accuracy: 0.3339 - val_loss: 1.7683
# Epoch 16/1000
# 101/101 ━━━━━━━━━━━━━━━━━━━━ 1s 14ms/step - accuracy: 0.3245 - loss: 1.7888 - val_accuracy: 0.3353 - val_loss: 1.7634
# Epoch 17/1000
# 101/101 ━━━━━━━━━━━━━━━━━━━━ 1s 13ms/step - accuracy: 0.3296 - loss: 1.7827 - val_accuracy: 0.3266 - val_loss: 1.7641
# Epoch 18/1000
# 101/101 ━━━━━━━━━━━━━━━━━━━━ 1s 13ms/step - accuracy: 0.3303 - loss: 1.7798 - val_accuracy: 0.3351 - val_loss: 1.7600
# Epoch 19/1000
# 101/101 ━━━━━━━━━━━━━━━━━━━━ 1s 13ms/step - accuracy: 0.
1000
# 101/101 ━━━━━━━━━━━━━━━━━━━━ 1s 14ms/step - accuracy: 0.3597 - loss: 1.6965 - val_accuracy: 0.3705 - val_loss: 1.6668
# Epoch 83/1000
# 101/101 ━━━━━━━━━━━━━━━━━━━━ 1s 13ms/step - accuracy: 0.3708 - loss: 1.6907 - val_accuracy: 0.3378 - val_loss: 1.7591
# Epoch 84/1000
# 101/101 ━━━━━━━━━━━━━━━━━━━━ 1s 14ms/step - accuracy: 0.3624 - loss: 1.6985 - val_accuracy: 0.3798 - val_loss: 1.6554
# Epoch 85/1000
# 101/101 ━━━━━━━━━━━━━━━━━━━━ 1s 14ms/step - accuracy: 0.3698 - loss: 1.6845 - val_accuracy: 0.3790 - val_loss: 1.6517
# Epoch 86/1000
# 101/101 ━━━━━━━━━━━━━━━━━━━━ 1s 13ms/step - accuracy: 0.3686 - loss: 1.6809 - val_accuracy: 0.3760 - val_loss: 1.6539
# Epoch 87/1000
# 101/101 ━━━━━━━━━━━━━━━━━━━━ 1s 13ms/step - accuracy: 0.3705 - loss: 1.6891 - val_accuracy: 0.3805 - val_loss: 1.6492
# Epoch 88/1000
# 101/101 ━━━━━━━━━━━━━━━━━━━━ 2s 16ms/step - accuracy: 0.3702 - loss: 1.6807 - val_accuracy: 0.3385 - val_loss: 1.7027
# Epoch 89/1000
# 101/101 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - accuracy: 0.3669 - loss: 1.6924 - val_accuracy: 0.3795 - val_loss: 1.6538
# Epoch 90/1000
# 101/101 ━━━━━━━━━━━━━━━━━━━━ 1s 13ms/step - accuracy: 0.3638 - loss: 1.6896 - val_accuracy: 0.3426 - val_loss: 1.8099
# Epoch 91/1000
# 101/101 ━━━━━━━━━━━━━━━━━━━━ 1s 13ms/step - accuracy: 0.3412 - loss: 1.7716 - val_accuracy: 0.3378 - val_loss: 1.7107
# Epoch 92/1000
# 101/101 ━━━━━━━━━━━━━━━━━━━━ 2s 16ms/step - accuracy: 0.3545 - loss: 1.7201 - val_accuracy: 0.3429 - val_loss: 1.6800
# Epoch 93/1000
# 101/101 ━━━━━━━━━━━━━━━━━━━━ 2s 15ms/step - accuracy: 0.3642 - loss: 1.7012 - val_accuracy: 0.3796 - val_loss: 1.6641
# Epoch 94/1000
# 101/101 ━━━━━━━━━━━━━━━━━━━━ 1s 14ms/step - accuracy: 0.3686 - loss: 1.6916 - val_accuracy: 0.3456 - val_loss: 1.7200
# Epoch 95/1000
# 101/101 ━━━━━━━━━━━━━━━━━━━━ 1s 14ms/step - accuracy: 0.3630 - loss: 1.7004 - val_accuracy: 0.3415 - val_loss: 1.8248
# Epoch 96/1000
# 101/101 ━━━━━━━━━━━━━━━━━━━━ 1s 14ms/step - accuracy: 0.3234 - loss: 1.8032 - val_accuracy: 0.3422 - val_loss: 1.7315
# Epoch 97/1000
# 101/101 ━━━━━━━━━━━━━━━━━━━━ 1s 14ms/step - accuracy: 0.3381 - loss: 1.7556 - val_accuracy: 0.3422 - val_loss: 1.7297
# Run 2/5 started...
# Run 3/5 started...
# Run 4/5 started...
# Run 5/5 started...
#
# Aggregated Metrics:
# test_loss: 1.8021
# test_accuracy: 0.1461
# balanced_accuracy: 0.4276
# roc_auc: 0.7537
# pr_auc: 0.8315
# f2: 0.1418
# mcc: 0.1450
# 0_precision: 0.5907
# 0_recall: 0.0906
# 0_f1-score: 0.1443
# 0_support: 26862.0000
# 1_precision: 0.3429
# 1_recall: 0.3621
# 1_f1-score: 0.3344
# 1_support: 2657.0000
# 2_precision: 0.2926
# 2_recall: 0.8322
# 2_f1-score: 0.3751
# 2_support: 908.0000
# 3_precision: 0.3401
# 3_recall: 0.3054
# 3_f1-score: 0.3021
# 3_support: 522.0000
# 4_precision: 0.1880
# 4_recall: 0.3509
# 4_f1-score: 0.1758
# 4_support: 293.0000
# 5_precision: 0.0145
# 5_recall: 0.4238
# 5_f1-score: 0.0274
# 5_support: 269.0000
# 6_precision: 0.1229
# 6_recall: 0.5466
# 6_f1-score: 0.1638
# 6_support: 116.0000
# 7_precision: 0.0058
# 7_recall: 0.4189
# 7_f1-score: 0.0115
# 7_support: 53.0000
# 8_precision: 0.0487
# 8_recall: 0.5182
# 8_f1-score: 0.0767
# 8_support: 44.0000
# accuracy: 0.1461
# macro avg_precision: 0.2162
# macro avg_recall: 0.4276
# macro avg_f1-score: 0.1790
# macro avg_support: 31724.0000
# weighted avg_precision: 0.5453
# weighted avg_recall: 0.1461
# weighted avg_f1-score: 0.1685
# weighted avg_support: 31724.0000
